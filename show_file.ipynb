# %%
import pandas as pd
import re
import unicodedata

# Your raw CSV
INPUT_CSV = "9700cases.csv"
OUTPUT_CSV = "9700cases_clean.csv"

df = pd.read_csv(INPUT_CSV)

def clean_text(val):
    if pd.isna(val):
        return ""

    # Normalize Unicode
    val = unicodedata.normalize("NFKD", str(val))

    # Replace newlines with spaces
    val = val.replace("\n", " ").replace("\r", " ")

    # Only allow SAFE ASCII characters
    # Keep: letters, numbers, space, comma, dot, dash, colon, slash,
    # quotes, apostrophe, parentheses, ?, ! 
    val = re.sub(r"[^A-Za-z0-9 ,\.\-\:\;\/\(\)\'\"\?\!]", " ", val)

    # Collapse multiple spaces
    val = re.sub(r"\s+", " ", val)

    return val.strip()

# Clean every column
for col in df.columns:
    df[col] = df[col].apply(clean_text)

df.to_csv(OUTPUT_CSV, index=False)

print("CLEAN CSV SAVED →", OUTPUT_CSV)
df.head()
# Out:
# CLEAN CSV SAVED → 9700cases_clean.csv
#                                           Case Title  \
# 0  The State Of Tamil Nadu vs The Governor Of Tam...
# 1  Directorate Of Revenue Intelligence vs Raj Kum...
# 2  Independent Sugar Corporation Limited vs Giris...
# 3  Pinki vs The State Of Uttar Pradesh on 15 Apri...
# 4  Piramal Capital And Housing Finance ... vs 63 ...
#
#                                                 Link  \
# 0  https://indiankanoon.org/docfragment/82729634/...
# 1  https://indiankanoon.org/docfragment/92625542/...
# 2  https://indiankanoon.org/docfragment/117249167...
# 3  https://indiankanoon.org/docfragment/173333132...
# 4  https://indiankanoon.org/docfragment/190999006...
#
#                                                Issue  \
# 0  J.B. PARDIWALA, J. 8, CONSTITUENT ASSEMB. DEB....
# 1  J.B. PARDIWALA, J.: Criminal Appeal No. 1319 o...
# 2  Hrishikesh Roy, J. FACTUAL MATRIX 1. These are...
# 3  i. FIR No. 193/2023 (in Sanjay v. State of Utt...
# 4  (I) THE DETAILS AND CATEGORIES OF THE APPEALS:...
#
#                                   Precedent Analysis  \
# 0  For the convenience of the exposition, this ju...
# 1  16. Aggrieved by the aforesaid order dated 30....
# 2  2. One key party in this matter is HNGIL i.e.,...
# 3  J. B. PARDIWALA, J. For the convenience of exp...
# 4  3. In these long-drawn proceedings, the Factua...
#
#                                  Analysis of the law  \
# 0  STATE LIST Entry 32 -- Incorporation, regulati...
# 1  Thus it being Schedule H drug, it would fall w...
# 2  20.1. It was argued that the RP adhered to the...
# 3  against Transnational Organised Crime, traffic...
# 4  iii. Section 36 (A) of the NHB Act and Section...
#
#                                                 Fact  \
# 0  3. The Legislature for the State of Tamil Nadu...
# 1  The DRI(HQ) officers recovered 25 corrugated c...
# 2  3. Combining with HNGIL is AGI Greenpac Ltd. h...
# 3  a ) The present case pertains to an interstate...
# 4  1. In the captioned Appeals, the contextual fa...
#
#                                Respondent's Argument  \
# 0  22. The petitioner, on the other hand, has ave...
# 1  25. It was submitted that the respondent no. 3...
# 2  9. On 22.10.2022, CCI declared the application...
# 3  16. The level of awareness about schemes and p...
# 4  promoters challenging the impugned order dated...
#
#                                Petitioner's Argument  \
# 0  31. Mr. Rakesh Dwivedi, the learned Senior Cou...
# 1  9. The Chemical Examiner of the Central Revenu...
# 2  18. Dr. Abhishek Manu Singhvi, learned senior ...
# 3  6. Most of the Government official stated that...
# 4  Hence, the present set of Appeals have been fi...
#
#                                    Court's Reasoning  \
# 0  4. This Court issued notice to the respondents...
# 1  13. The appellant had preferred a petition for...
# 2  42. Where the language is clear, plain and una...
# 3  mechanism for children who are unable to live ...
# 4  ix. However, thereafter considering the comple...
#
#                                           Conclusion
# 0  241. What emerges from the above is that the f...
# 1  In these circumstances it would be appropriate...
# 2  126. The CCI was obligated to issue an appropr...
# 3  8. The concerned accused despite service have ...
# 4  45. Keeping in view the above settled legal po...

# %%
import pandas as pd
import toons

INPUT_CSV = "9700cases_clean.csv"
OUTPUT_TOON = "9700cases.toon"

df = pd.read_csv(INPUT_CSV)

records = df.to_dict(orient="records")

toon_text = toons.dumps(records)

with open(OUTPUT_TOON, "w", encoding="utf-8") as f:
    f.write(toon_text)

print("TOON SAVED →", OUTPUT_TOON)
# Out:
# TOON SAVED → 9700cases.toon

# %%
import toons

with open("9700cases.toon", "r", encoding="utf-8") as f:
    text = f.read()

records = toons.loads(text)
print("Parsed:", len(records), "rows")
# Out:
# Parsed: 9760 rows
