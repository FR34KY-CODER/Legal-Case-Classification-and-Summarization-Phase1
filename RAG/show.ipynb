# %%
import pandas as pd
df = pd.read_csv(r"V:\BTP\9700cases.csv")
df.head()
# Out:
#                                           Case Title  \
# 0  The State Of Tamil Nadu vs The Governor Of Tam...
# 1  Directorate Of Revenue Intelligence vs Raj Kum...
# 2  Independent Sugar Corporation Limited vs Giris...
# 3  Pinki vs The State Of Uttar Pradesh on 15 Apri...
# 4  Piramal Capital And Housing Finance ... vs 63 ...
#
#                                                 Link  \
# 0  https://indiankanoon.org/docfragment/82729634/...
# 1  https://indiankanoon.org/docfragment/92625542/...
# 2  https://indiankanoon.org/docfragment/117249167...
# 3  https://indiankanoon.org/docfragment/173333132...
# 4  https://indiankanoon.org/docfragment/190999006...
#
#                                                Issue  \
# 0  J.B. PARDIWALA, J.\n\n8, CONSTITUENT ASSEMB. D...
# 1  J.B. PARDIWALA, J.:\n\nCriminal Appeal No. 131...
# 2  Hrishikesh Roy, J.\nFACTUAL MATRIX\n1.      Th...
# 3  i.     FIR No. 193/2023 (in\nSanjay v. State o...
# ...

# %%
df1 = pd.read_csv(r"data\710edited.csv")
df1.head()
# Out:
#                                                title  \
# 0  The State Of Tamil Nadu vs The Governor Of Tam...
# 1  Independent Sugar Corporation Limited vs Giris...
# 2  Piramal Capital And Housing Finance ... vs 63 ...
# 3  In Re Recruitment Of Visually Impaired ... vs ...
# 4  Union Of India vs Future Gaming Solutions P.Lt...
#
#                                              content         id
# 0  J.B. PARDIWALA, J.\nFor the convenience of the...   82729634
# 1  Hrishikesh Roy, J.\nFACTUAL MATRIX\n1.      Th...  117249167
# 2  1.    In the captioned Appeals, the contextual...  190999006
# 3  R. MAHADEVAN, J.\nLeave granted. This judgment...  158218833
# 4  INDEX\n\n\n\nHistory of this controversy: .......  117744026
