# %%
# import json

# taxonomy = {
#     "LABOUR MATTERS": {
#         "Dismissal": {
#             "Description": "Cases involving termination of employment, disciplinary actions, and procedural fairness in employment termination. These cases typically address issues of misconduct investigations, show-cause procedures, compliance with natural justice principles, validity of departmental inquiries, and legal challenges to termination decisions. The matters often revolve around procedural irregularities, evidence evaluation in disciplinary proceedings, and the rights of employees during termination processes.",
#             "Keywords": ["termination", "misconduct", "disciplinary action", "show cause notice", "natural justice violation", "departmental inquiry", "charge sheet", "termination benefits", "wrongful dismissal", "disciplinary proceedings", "procedural fairness", "inquiry report", "punishment proportionality", "reinstatement", "back wages"],
#             "embeddings": None 
#         },
#         "Retrenchment": {
#             "Description": "Cases concerning reduction of workforce, closure of establishments, and legal compliance with retrenchment procedures. These matters involve interpretation of retrenchment compensation calculations, compliance with statutory notice periods, government permissions for large-scale retrenchment, application of \"last in first out\" principle, and challenges to closure decisions. The cases often address economic reasons justification, alternative employment arrangements, and worker rehabilitation measures.",
#             "Keywords": ["retrenchment compensation", "section 25N", "layoff", "closure", "retrenchment notice", "industrial disputes act 1947", "compensation calculation", "last come first go", "government permission", "retrenchment approval", "workforce reduction", "establishment closure", "retrenchment legality", "severance package", "voluntary retirement scheme"],
#             "embeddings": None 
#         },
#         "Contract Labour": {
#             "Description": "Cases dealing with regulation of contract labor, responsibilities of principal employers, and rights of contract workers. These matters involve determinations of genuine versus sham contract arrangements, licensing requirements for contractors, application of abolition notifications, and liabilities for unpaid wages or benefits. The cases often address triangular employment relationships, compliance with contract labor regulations, and claims for regularization of contract workers.",
#             "Keywords": ["contract labour regulation", "principal employer", "licensing contractor", "abolition notification", "sham contract", "tripartite agreement", "labour commissioner", "contract worker benefits", "section 10", "direct employment", "labor contractor", "manpower supplier", "deemed employment", "equal pay equal work", "contract labor prohibition"],
#             "embeddings": None 
#         },
#         "Matters relating to wages": {
#             "Description": "Cases concerning wage disputes, salary structures, and remuneration rights under various labor laws. These matters involve claims for minimum wage compliance, dearness allowance revisions, pay parity disputes, arrears calculations, and wage board recommendations implementation. The cases often address interpretations of wage definitions, overtime calculations, and comparative wage structures across industries.",
#             "Keywords": ["minimum wages", "wage revision", "dearness allowance", "pay parity", "arrears calculation", "wage board", "equal remuneration", "basic pay", "allowances dispute", "wage regularization", "overtime wages", "bonus payment", "salary structure", "wage fixation", "pay commission recommendations"],
#             "embeddings": None 
#         },
#         "Workmen Compensation Act": {
#             "Description": "Cases involving compensation for employment-related injuries, occupational diseases, and employer liability for workplace accidents. These matters address assessment of disablement percentages, dependency benefit calculations, occupational disease notifications, and employer insurance requirements. The cases often involve medical evidence evaluation, causal connection between employment and injury, and compensation commissioner appeals.",
#             "Keywords": ["employment injury schedule iii", "section 3 employer liability", "occupational disease notification", "disablement percentage assessment", "compensation commissioner appeal", "dependency benefits calculation", "employer liability insurance", "accident arising employment", "mesothelioma compensation", "silicosis diagnosis report", "work-related injury", "permanent disability", "temporary disablement", "compensation calculation", "employer negligence"],
#             "embeddings": None 
#         },
#         "ESI": {
#             "Description": "Cases pertaining to Employees' State Insurance benefits, contribution compliance, and medical care entitlements. These matters involve disputes over ESI registration, contribution calculations, medical benefit claims, disability assessments, and dependent benefits. The cases often address eligibility criteria, contribution periods, and interpretation of ESI regulations for different establishment types.",
#             "Keywords": ["employees state insurance", "esi contribution", "medical benefit", "disability benefit", "dependent benefit", "esi corporation", "section 46", "insurable employment", "registration certificate", "benefit period", "esi hospital", "sickness benefit", "maternity benefit", "medical board", "contribution recovery"],
#             "embeddings": None 
#         },
#         "Factory Act": {
#             "Description": "Cases concerning compliance with factory regulations, occupational health and safety standards, and working conditions in manufacturing establishments. These matters involve factory licensing requirements, occupier liabilities, hazardous process regulations, and safety measure implementations. The cases often address violations of health standards, safety officer appointments, and worker facility provisions.",
#             "Keywords": ["factory license", "occupier liability", "hazardous process", "section 7A", "annual leave", "health measures", "safety officer", "canteen facilities", "creche facility", "dangerous machinery", "factory premises", "safety standards", "occupational health", "working hours", "hazardous chemicals"],
#             "embeddings": None 
#         },
#         "Industrial Employment (Standing Order)": {
#             "Description": "Cases dealing with certification of standing orders, service condition regulations, and workplace rule implementations. These matters involve disputes over standing order certifications, classification of workers, shift working arrangements, and leave rule applications. The cases often address modifications to standing orders, disciplinary procedures, and grievance redressal mechanisms.",
#             "Keywords": ["standing order certification", "service rules", "shift working", "attendance", "leave rules", "classification of workers", "suspension pending inquiry", "holiday list", "termination procedure", "grievance redressal", "certified standing orders", "service conditions", "work rules", "misconduct definition", "inquiry procedure"],
#             "embeddings": None 
#         },
#         "Payment of Gratuity Act": {
#             "Description": "Cases involving gratuity payments, eligibility criteria, and calculation disputes upon termination of employment. These matters address gratuity calculation methods, forfeiture conditions, employer default in payment, and recovery procedures. The cases often involve interpretations of continuous service, superannuation definitions, and valid grounds for gratuity denial.",
#             "Keywords": ["gratuity calculation", "section 4", "forfeiture of gratuity", "gratuity eligibility", "employer default", "gratuity recovery", "superannuation", "continuous service", "gratuity payment", "nomination", "gratuity authority", "time limit", "gratuity claim", "maximum gratuity", "gratuity dispute"],
#             "embeddings": None 
#         },
#         "Trade Unions Act": {
#             "Description": "Cases concerning trade union registration, recognition disputes, and collective bargaining rights. These matters involve trade union registration procedures, recognition disputes, unfair labor practice allegations, and union election controversies. The cases often address verification of membership claims, protected workmen status, and collective bargaining agreement interpretations.",
#             "Keywords": ["trade union registration", "section 8", "unfair labor practice", "recognition dispute", "union elections", "membership verification", "collective bargaining", "union funds", "protected workmen", "union rivalry", "trade union rights", "collective agreement", "union recognition", "labor practices", "union activities"],
#             "embeddings": None 
#         }
#     },
    
#     "RENT ACT MATTERS": {
#         "Eviction matters of personal necessity": {
#             "Description": "Cases involving eviction petitions filed by landlords for bona fide personal requirement of the premises. These matters address genuine needs for self-occupation, family expansion requirements, comparative hardship between landlord and tenant, and adequacy of alternative accommodation arrangements. The cases typically involve detailed examination of landlord's actual requirements, family circumstances, and the authenticity of the claimed necessity.",
#             "Keywords": ["bona fide need", "self-occupation", "family expansion", "alternative accommodation", "comparative hardship", "landlord requirement", "residential purpose", "dependent family", "business expansion", "medical necessity", "genuine requirement", "personal use", "family member accommodation", "commercial need", "occupation bona fides"],
#             "embeddings": None 
#         },
#         "Eviction matters for re-building": {
#             "Description": "Cases concerning eviction for substantial reconstruction, demolition, or redevelopment of premises. These matters involve structural safety concerns, municipal notices for demolition, architectural certifications, redevelopment agreements, and tenant rehabilitation plans. The cases typically examine the bona fides of reconstruction plans, financial arrangements for rebuilding, and temporary accommodation arrangements for displaced tenants.",
#             "Keywords": ["structural alteration", "demolition notice", "municipal notice", "reconstruction plan", "architect certificate", "building stability", "redevelopment agreement", "tenant relocation", "construction permission", "completion bond", "structural safety", "rebuilding necessity", "development permission", "temporary accommodation", "restoration guarantee"],
#             "embeddings": None 
#         },
#         "Eviction matters of sub-letting": {
#             "Description": "Cases involving unauthorized sub-letting, parting with possession, and illegal transfer of tenancy rights. These matters address allegations of sub-letting without consent, creation of license agreements, possession by third parties, and violation of tenancy terms. The cases typically involve evidence of rent receipts to third parties, possession patterns, and documentation of unauthorized arrangements.",
#             "Keywords": ["unauthorized occupant", "sub-tenant", "parting possession", "license agreement", "tenancy rights", "rent receipt", "tenant verification", "lock-out period", "lease violation", "third party possession", "illegal transfer", "consent requirement", "tenancy violation", "possession proof", "sub-letting evidence"],
#             "embeddings": None 
#         },
#         "Arrears of rent": {
#             "Description": "Cases concerning non-payment of rent, calculation of arrears, and recovery of dues from tenants. These matters involve disputes over standard rent fixation, monthly rent payments, default periods, interest calculations on arrears, and deposit schemes. The cases typically examine rent payment records, notice periods for demand, and validity of rent enhancement claims.",
#             "Keywords": ["rent default", "monthly rent", "standard rent", "rent enhancement", "deposit scheme", "tenant default", "arrears calculation", "interest on arrears", "money decree", "rent receipt", "rent demand", "payment default", "arrears recovery", "rent determination", "payment proof"],
#             "embeddings": None 
#         },
#         "Enhancement of rent": {
#             "Description": "Cases involving applications for rent increase based on fair rent principles, market rates, and statutory provisions. These matters address fair rent fixation, market rate determinations, cost index applications, capital value assessments, and improvement cost considerations. The cases typically involve expert valuation reports, comparative rent analyses, and interpretations of rent control legislation provisions.",
#             "Keywords": ["fair rent", "market rate", "rent control act", "cost index", "capital value", "improvement cost", "section 6", "prevailing rent", "landlord application", "tenant objection", "rent fixation", "valuation report", "reasonable rent", "statutory enhancement", "rent revision"],
#             "embeddings": None 
#         }
#     },

#     "DIRECT TAXES MATTER": {
#         "Income Tax Reference": {
#             "Description": "Cases involving references to High Courts on substantial questions of law arising from Income Tax Appellate Tribunal orders. These matters address complex legal interpretations of tax provisions, jurisdictional issues, and substantial questions of law requiring judicial clarification. The cases typically examine whether a question of law arises from tribunal decisions, the substantiality of the legal issue, and the proper interpretation of tax statutes in contentious matters.",
#             "Keywords": ["substantial question of law", "section 256", "high court reference", "tax tribunal order", "case stated", "appellate reference", "tax evasion", "assessment year", "revision petition", "tax deduction", "legal interpretation", "tribunal order", "tax appeal", "reference jurisdiction", "question of law"],
#             "embeddings": None 
#         },
#         "Wealth Tax Act": {
#             "Description": "Cases concerning valuation and taxation of net wealth under the Wealth Tax Act. These matters involve disputes over asset valuation methodologies, classification of assets as productive or unproductive, valuation date determinations, and exemptions claims. The cases typically address property valuations, jewellery assessments, urban land classifications, and compliance with wealth tax return filing requirements.",
#             "Keywords": ["net wealth", "asset valuation", "urban land", "unproductive assets", "valuation date", "wealth statement", "exempt assets", "jewellery valuation", "section 17 wealth tax", "wealth tax return", "asset classification", "valuation method", "wealth computation", "taxable wealth", "assessment proceedings"],
#             "embeddings": None 
#         },
#         "Capital Gains": {
#             "Description": "Cases involving taxation of capital gains from transfer of capital assets under income tax provisions. These matters address determinations of capital asset classification, transfer definitions under section 2(47), indexation benefits, long-term versus short-term gains, and exemption claims under various sections. The cases typically examine sale consideration valuations, cost inflation index applications, and exemption eligibility criteria.",
#             "Keywords": ["capital asset", "transfer u/s 2(47)", "indexation benefit", "long term gain", "cost inflation index", "section 54", "exemption claim", "sale consideration", "capital gains bond", "stamp duty value", "capital gains computation", "transfer definition", "exemption qualification", "indexed cost", "capital gains tax"],
#             "embeddings": None 
#         },
#         "Re-assessment": {
#             "Description": "Cases concerning reopening of income tax assessments beyond the normal assessment period. These matters address validity of reassessment proceedings under section 147, reasons recorded for income escapement, fresh material discoveries, and limitation period compliance. The cases typically examine whether reassessment is based on change of opinion or new information, and the jurisdictional validity of reopening assessments.",
#             "Keywords": ["reopening assessment", "section 147", "income escapement", "reasons recorded", "change of opinion", "fresh material", "limitation period", "notice validity", "concealment income", "undisclosed investment", "reassessment validity", "income suppression", "new information", "jurisdictional grounds", "reassessment proceedings"],
#             "embeddings": None 
#         },
#         "Settlement Commission": {
#             "Description": "Cases involving applications before the Income Tax Settlement Commission for resolution of tax disputes through settlement mechanisms. These matters address full disclosure requirements, immunity petitions, settlement terms negotiation, and finality of settlement orders. The cases typically examine the maintainability of settlement applications, disclosure completeness, and the commission's jurisdiction in pending cases.",
#             "Keywords": ["settlement application", "full disclosure", "immunity petition", "settlement order", "undisclosed income", "section 245C", "commission hearing", "settlement terms", "case pending", "finality of order", "settlement jurisdiction", "disclosure adequacy", "immunity grant", "settlement terms", "commission powers"],
#             "embeddings": None 
#         }
#     },

#     "INDIRECT TAXES MATTERS": {
#         "Interpretation of the Customs Act": {
#             "Description": "Cases involving the interpretation and application of provisions under the Customs Act, 1962, including valuation of imported goods, classification disputes, exemption claims, and procedural compliance requirements. These matters address determinations of customs value under Section 14, validity of bills of entry, baggage rule applications, prohibited goods classifications, and project import regulations. The cases typically examine customs duty calculations, exemption certificate validities, import manifest compliance, and appellate mechanisms under customs law.",
#             "Keywords": ["customs valuation", "bill of entry", "section 14", "import manifest", "baggage rules", "prohibited goods", "customs duty exemption", "project imports", "redeployment certificate", "customs appeal", "customs duty", "goods classification", "import regulation", "duty calculation", "customs procedures"],
#             "embeddings": None 
#         },
#         "Central Excise Act": {
#             "Description": "Cases concerning the manufacture, removal, and taxation of excisable goods under the Central Excise Act, 1944 and related regulations. These matters address determinations of what constitutes a manufacturing process, CENVAT credit availment and utilization, duty demand notices, MODVAT schemes, and factory gate clearances. The cases typically involve interpretations of excise tariff classifications, valuation of excisable goods, compliance with Rule 6 provisions, and remission of duty procedures.",
#             "Keywords": ["excisable goods", "cenvat credit", "manufacturing process", "rule 6", "clearance certificate", "duty demand notice", "modvat", "central excise tariff", "factory gate", "removal of goods", "excise duty", "manufacture definition", "credit utilization", "duty payment", "excise assessment"],
#             "embeddings": None 
#         },
#         "Service Tax": {
#             "Description": "Cases involving the levy, assessment, and recovery of service tax under the Finance Act, 1994, covering diverse service categories and compliance requirements. These matters address determinations of taxable services, reverse charge mechanisms, mega exemption notifications, place of provision rules, and point of taxation concepts. The cases typically examine export of service qualifications, input service distributor mechanisms, works contract compositions, and service tax audit procedures.",
#             "Keywords": ["taxable service", "reverse charge", "mega exemption", "place of provision", "point of taxation", "export of service", "input service distributor", "service tax audit", "abatement claim", "works contract", "service tax", "tax liability", "exemption notification", "service classification", "tax assessment"],
#             "embeddings": None 
#         },
#         "Anti Dumping Duty": {
#             "Description": "Cases concerning the imposition and review of anti-dumping duties to protect domestic industries from unfairly priced imported goods under the Customs Tariff Act, 1975. These matters address calculations of dumping margins, injury determinations to domestic industry, designated authority investigations, and like article comparisons. The cases typically examine normal value determinations, landed value calculations, provisional duty impositions, sunset reviews, and reference price establishments.",
#             "Keywords": ["margin of dumping", "injury determination", "designated authority", "like article", "normal value", "landed value", "provisional duty", "sunset review", "domestic industry", "reference price", "dumping duty", "trade remedy", "injury analysis", "investigation procedure", "duty imposition"],
#             "embeddings": None 
#         }
#     },

#     "CRIMINAL MATTERS": {
#         "Capital punishment": {
#             "Description": "Cases involving the imposition and confirmation of the death penalty, representing the most severe punishment in the criminal justice system. These matters address the \"rarest of rare\" doctrine, balancing aggravating and mitigating circumstances, and constitutional challenges to capital punishment. The cases typically involve exhaustive review of crime brutality, criminal antecedents, rehabilitation possibilities, and societal impact, with multiple layers of judicial scrutiny from trial courts to Supreme Court confirmation hearings.",
#             "Keywords": ["rarest of rare", "death sentence confirmation", "section 302 IPC", "aggravating factors", "mitigating circumstances", "deterrent punishment", "execution warrant", "mercy petition", "death row convict", "commutation plea", "capital punishment", "sentence balancing", "constitutional validity", "judicial review", "sentencing philosophy"],
#             "embeddings": None 
#         },
#         "Dowry death": {
#             "Description": "Cases involving deaths of married women under suspicious circumstances within seven years of marriage, with allegations of dowry-related harassment. These matters address statutory presumptions under Section 304B IPC, proof of dowry demands \"soon before death,\" and evidence of cruelty and harassment. The cases typically examine matrimonial history, financial transactions, domestic violence patterns, and the recovery of stridhan (bridal wealth).",
#             "Keywords": ["section 304B", "dowry demand", "soon before death", "cruelty evidence", "stridhan recovery", "domestic violence", "marriage harassment", "dowry prohibition", "bride burning", "death within 7 years", "dowry harassment", "statutory presumption", "matrimonial cruelty", "harassment proof", "dowry death presumption"],
#             "embeddings": None 
#         },
#         "Prevention of Corruption Act": {
#             "Description": "Cases involving corruption offenses by public servants, including bribery, illegal gratification, and possession of disproportionate assets. These matters address trap cases, validity of sanction for prosecution, evidence of demand and acceptance of bribes, and calculations of disproportionate wealth. The cases typically involve vigilance investigations, recovery operations, and examination of asset declarations versus known income sources.",
#             "Keywords": ["illegal gratification", "trap case", "disproportionate assets", "section 13", "public servant", "vigilance inquiry", "sanction prosecution", "bribe money", "demand proof", "recovery certificate", "corruption offense", "public duty abuse", "wealth discrepancy", "graft evidence", "anticorruption law"],
#             "embeddings": None 
#         },
#         "NDPS Act": {
#             "Description": "Cases involving offenses under the Narcotic Drugs and Psychotropic Substances Act, covering possession, trafficking, and distribution of controlled substances. These matters address determinations of commercial quantities, conscious possession requirements, compliance with sampling and seizure procedures, and mandatory minimum sentences. The cases typically examine chain of custody evidence, independent witness reliability, and forensic analysis of contraband.",
#             "Keywords": ["commercial quantity", "psychotropic substance", "section 37", "conscious possession", "sampling procedure", "independent witness", "mandatory minimum", "contraband seizure", "drug analysis", "cartel involvement", "narcotics offense", "controlled substance", "trafficking quantity", "seizure compliance", "drug trade"],
#             "embeddings": None 
#         },
#         "Sexual harassment": {
#             "Description": "Cases involving various forms of sexual offenses against women, including outraging modesty, workplace harassment, stalking, and voyeurism. These matters address evidence collection in sensitive cases, victim protection mechanisms, compensation awards, and implementation of the POSH Act for workplace safety. The cases typically examine victim testimony reliability, circumstantial evidence, and the psychological impact on survivors.",
#             "Keywords": ["section 354", "modesty outrage", "voyeurism", "stalking", "workplace harassment", "POSH Act", "zero FIR", "acid attack", "compensation award", "victim protection", "sexual offense", "women safety", "harassment evidence", "victim testimony", "gender-based violence"],
#             "embeddings": None 
#         }
#     },

#     "SERVICE MATTERS": {
#         "Promotion": {
#             "Description": "Cases involving disputes related to promotion policies, seniority considerations, departmental promotion committees, and implementation of reservation rosters in government and public sector employment. These matters address criteria for promotion, merit versus seniority balances, sealed cover procedures for pending disciplinary cases, and the proper constitution and functioning of DPCs. The cases typically examine promotion policies, eligibility lists, benchmarking standards, and notional promotions with consequential benefits.",
#             "Keywords": ["seniority cum merit", "departmental promotion", "reservation roster", "sealed cover procedure", "dpc meeting", "eligible list", "promotion criteria", "benchmarking", "notional promotion", "promotion policy", "seniority list", "promotion quota", "selection process", "promotion dispute", "departmental promotion committee"],
#             "embeddings": None 
#         },
#         "Pension": {
#             "Description": "Cases concerning pensionary benefits, revisions, commutations, family pensions, and gratuity payments for government employees and public sector workers. These matters address qualifying service calculations, pension sanction procedures, delays in pension processing, invalid pension claims, and pension cuts due to disciplinary actions. The cases typically involve interpretations of pension rules, revision schemes, and entitlement determinations based on service duration and conditions.",
#             "Keywords": ["pension revision", "commutation amount", "family pension", "gratuity payment", "pension sanction", "qualifying service", "invalid pension", "delay in pension", "pension cut", "pensionary benefits", "pension calculation", "retirement benefits", "pension entitlement", "pension disbursement", "superannuation benefits"],
#             "embeddings": None 
#         },
#         "Disciplinary proceedings": {
#             "Description": "Cases involving departmental inquiries, charge memos, penalty impositions, and procedural compliance in disciplinary actions against employees. These matters address evidence act applications in departmental inquiries, validity of charge sheets, proportionality of punishments, CVC guideline compliance, and inquiry procedure fairness. The cases typically examine inquiry officer appointments, defense assistant rights, ex parte proceedings, and the distinction between minor and major penalties.",
#             "Keywords": ["charge memo", "departmental inquiry", "evidence act violation", "punishment order", "minor penalty", "major penalty", "cvc guidelines", "inquiry officer", "defense assistant", "ex parte inquiry", "disciplinary action", "procedural fairness", "penalty imposition", "inquiry report", "misconduct proof"],
#             "embeddings": None 
#         },
#         "Reservation in service": {
#             "Description": "Cases concerning implementation of reservation policies, creamy layer exclusions, roster systems, and carry forward rules in public employment. These matters address Mandal Commission recommendations, reservation ceilings, promotion reservations, social backwardness determinations, and caste certificate validities. The cases typically examine income criteria for creamy layer exclusion, roster point operations, and constitutional validity of various reservation provisions.",
#             "Keywords": ["creamy layer reservation", "reservation policy service", "mandal commission", "roster system", "carry forward rule", "promotion reservation", "reservation ceiling", "social backwardness", "income criteria", "caste certificate", "reservation quota", "backward class", "reservation entitlement", "roster point", "caste validity"],
#             "embeddings": None 
#         },
#         "Voluntary Retirement": {
#             "Description": "Cases involving voluntary retirement schemes, acceptance conditions, distinction from resignation, and post-retirement benefits. These matters address VR scheme eligibility, notice period requirements, pension eligibility after voluntary retirement, forced retirement allegations, and golden handshake arrangements. The cases typically examine whether retirement was truly voluntary, compliance with scheme conditions, and calculation of retirement benefits under voluntary separation plans.",
#             "Keywords": ["vr scheme", "acceptance condition", "resignation difference", "pension eligibility", "notice period", "vr benefits", "forced retirement", "section 18", "voluntary separation", "golden handshake", "voluntary retirement", "retirement benefits", "scheme eligibility", "voluntary separation benefits", "retirement acceptance"],
#             "embeddings": None 
#         }
#     },

#     "LAND ACQUISITION & REQUISITION": {
#         "Compensation challenges": {
#             "Description": "Cases involving disputes over the adequacy and calculation of compensation awarded for land acquired under the Land Acquisition Act and related legislation. These matters address determinations of market value under Section 23, solatium payments, additional compensation claims, and valuation methodologies for different types of land. The cases typically examine expert valuation reports, potential value considerations, belting system applications, severance compensation for partial acquisitions, and compensation for injurious affection to remaining land.",
#             "Keywords": ["market value", "section 23", "solatium", "additional compensation", "potential value", "expert valuation", "land acquisition award", "belting system", "severance compensation", "injurious affection", "compensation dispute", "land valuation", "acquisition award", "value assessment", "compensation enhancement"],
#             "embeddings": None 
#         },
#         "Defence acquisition": {
#             "Description": "Cases concerning land acquisition for defence purposes, including the application of urgency clauses under Section 17, strategic requirements, and national security considerations. These matters address emergency acquisition procedures, defence production facility requirements, encroachment removal from defence lands, and establishment of buffer zones around sensitive installations. The cases typically examine the validity of urgency clause invocations, strategic purpose justifications, and compensation matters in defence-related acquisitions.",
#             "Keywords": ["urgency clause", "section 17 land acquisition", "defence production", "strategic purpose", "emergency acquisition", "national security", "encroachment removal", "defence installation", "buffer zone", "restricted area", "defence land", "strategic acquisition", "emergency powers", "security zone", "defence requirement"],
#             "embeddings": None 
#         }
#     },

#     "ACADEMIC MATTERS": {
#         "Examination matters": {
#             "Description": "Cases involving disputes related to examination processes, evaluation systems, and academic assessments across educational institutions. These matters address revaluation procedures, grace mark allocations, malpractice investigations, answer sheet inspection rights, and moderation policies. The cases typically examine the fairness of evaluation processes, validity of supplementary examinations, handling of paper leakages, prevention of unfair means, and transparency in marking schemes. The courts often balance institutional autonomy with students' rights to fair assessment.",
#             "Keywords": ["revaluation", "grace marks", "malpractice", "answer sheet inspection", "moderation policy", "supplementary exam", "re-test order", "paper leakage", "unfair means", "marking scheme", "examination process", "evaluation system", "answer script", "assessment fairness", "academic evaluation"],
#             "embeddings": None 
#         },
#         "Educational management": {
#             "Description": "Cases concerning the administration, regulation, and governance of educational institutions, including universities, colleges, and minority educational entities. These matters address deemed university status grants, minority institution rights, mandatory disclosure requirements, fee regulation compliance, and affiliation matters. The cases typically examine inspection report validity, teacher qualification standards, student union activities, anti-ragging measures, and implementation of reservation policies in educational institutions.",
#             "Keywords": ["deemed university", "minority institution", "mandatory disclosure", "inspection report", "fee regulation", "affiliation withdrawal", "teacher qualification", "student union", "anti-ragging", "reservation policy education", "educational governance", "institutional management", "regulatory compliance", "academic administration", "educational rights"],
#             "embeddings": None 
#         }
#     },

#     "LETTER PETITION & PIL MATTERS": {
#         "Environmental PIL": {
#             "Description": "Cases involving public interest litigation focused on environmental protection, conservation, and sustainable development principles. These matters address violations of environmental laws, improper clearances, ecological degradation, and implementation of environmental protection measures. The cases typically examine carbon emission standards, coastal regulation zone violations, forest clearance procedures, wildlife protection requirements, and application of the polluter pays principle. The courts often mandate environmental audits, remediation plans, and sustainable development practices while balancing ecological concerns with developmental needs.",
#             "Keywords": ["carbon emissions", "coastal regulation", "forest clearance", "wildlife protection", "environment clearance", "biosphere reserve", "polluter pays", "sustainable development", "remediation plan", "environmental audit", "ecological balance", "environmental protection", "conservation measures", "green principle", "climate justice"],
#             "embeddings": None 
#         },
#         "Human rights PIL": {
#             "Description": "Cases concerning public interest litigation aimed at protecting and promoting fundamental human rights, particularly for marginalized and vulnerable populations. These matters address custodial violence and deaths, prison condition reforms, eradication of manual scavenging, child rights protection, and rehabilitation of victims. The cases typically examine implementation of juvenile justice mechanisms, bonded labor eradication, compensation schemes for rights violations, victim protection measures, and access to legal aid for underprivileged communities.",
#             "Keywords": ["custodial death", "prison reform", "manual scavenging", "child rights", "rehabilitation plan", "bonded labour", "compensation scheme", "victim protection", "legal aid", "juvenile justice", "human rights violation", "dignity protection", "marginalised community", "rights enforcement", "social justice"],
#             "embeddings": None 
#         }
#     },

#     "ELECTION MATTERS": {
#         "Election petitions": {
#             "Description": "Cases involving challenges to the validity of election results, allegations of electoral malpractices, and disputes concerning the election process for various legislative bodies. These matters address corrupt practices such as bribery, undue influence, booth capturing, and false declarations in affidavits. The cases typically examine election expense violations, improper nomination rejections, demands for vote recounts, disputes over election symbols, result declaration procedures, electoral bond disclosures, and violations of the model code of conduct during elections.",
#             "Keywords": ["corrupt practice", "booth capturing", "false affidavit", "election expenses", "nomination rejection", "vote recount", "election symbol", "result declaration", "electoral bonds", "model code violation", "electoral malpractice", "election validity", "voting process", "candidate eligibility", "election dispute"],
#             "embeddings": None 
#         },
#         "MP/MLA disqualification": {
#             "Description": "Cases concerning the disqualification of elected representatives from legislative bodies on various constitutional and legal grounds. These matters address holding offices of profit, violations of anti-defection laws, validity of resignations, and cessation of membership. The cases typically examine disqualification petitions, floor test procedures, appointments to constitutional posts, legislative privileges, and allegations of breach of oath by elected representatives.",
#             "Keywords": ["office of profit", "defection law", "anti-defection", "resignation validity", "membership cessation", "disqualification petition", "floor test", "constitutional post", "legislative privileges", "breach of oath", "disqualification grounds", "legislative membership", "constitutional violation", "representative eligibility", "parliamentary conduct"],
#             "embeddings": None 
#         }
#     },

#     "COMPANY LAW, MRTP, SEBI": {
#         "SEBI matters": {
#             "Description": "Cases involving regulatory compliance, enforcement actions, and adjudication proceedings under the Securities and Exchange Board of India Act and related securities regulations. These matters address insider trading violations, substantial acquisition disclosures, takeover code compliance, fraudulent trade practices, and foreign institutional investor regulations. The cases typically examine disclosure norm violations, delisting procedures, share buyback offers, open offer requirements, and protection of investor interests in securities markets.",
#             "Keywords": ["insider trading", "substantial acquisition", "takeover code", "disclosure norms", "fraudulent trade", "FII regulations", "creamy layer investor", "delisting shares", "buyback offer", "open offer", "securities regulation", "market manipulation", "investor protection", "compliance violation", "capital market"],
#             "embeddings": None 
#         },
#         "Competition Commission": {
#             "Description": "Cases concerning anti-competitive practices, abuse of dominant position, cartelization, and combination regulations under the Competition Act. These matters address investigations into anti-competitive agreements, abuse of market dominance, leniency applications, penalty impositions based on turnover, and market share analyses. The cases typically examine predatory pricing allegations, vertical agreement restrictions, determinations of dominant position, and merger control regulations.",
#             "Keywords": ["anti-competitive", "abuse of dominance", "cartelization", "combination regulation", "leniency application", "turnover penalty", "market share", "predatory pricing", "vertical agreement", "dominant position", "competition law", "market regulation", "cartel investigation", "merger control", "anti-trust"],
#             "embeddings": None 
#         }
#     },

#     "ARBITRATION MATTERS": {
#         "Arbitration challenges": {
#             "Description": "Cases involving challenges to arbitral awards, appointment of arbitrators, and jurisdictional issues in domestic and international arbitration proceedings. These matters address setting aside awards under Section 34 of the Arbitration Act on grounds of patent illegality, public policy violations, and jurisdictional errors. The cases typically examine unilateral arbitrator appointments, emergency arbitrator provisions, interpretation of arbitration clauses, and distinctions between seat and venue of arbitration.",
#             "Keywords": ["arbitral award", "section 34", "patent illegality", "public policy", "arbitrator appointment", "jurisdictional error", "unilateral appointment", "emergency arbitrator", "arbitration clause", "seat vs venue", "award challenge", "arbitration agreement", "arbitral procedure", "jurisdictional challenge", "award enforcement"],
#             "embeddings": None 
#         }
#     },

#     "COMPENSATION MATTERS": {
#         "Railway accidents": {
#             "Description": "Cases involving claims for compensation arising from railway accidents, untoward incidents, and passenger injuries under the Railways Act and Fatal Accidents Act. These matters address railway liability determinations, track negligence allegations, passenger ticket validities, level crossing accidents, and compensation tariff applications. The cases typically examine dependency claims, railway tribunal procedures, and the extent of railway responsibility for accidents and incidents.",
#             "Keywords": ["untoward incident", "running train", "track negligence", "railway liability", "passenger ticket", "level crossing", "compensation tariff", "railway tribunal", "Fatal Accident Act", "dependency claim", "railway accident", "passenger safety", "accident compensation", "railway responsibility", "injury claim"],
#             "embeddings": None 
#         },
#         "Telecom disputes": {
#             "Description": "Cases involving disputes in the telecommunications sector, including service quality issues, regulatory compliance, and compensation claims. These matters address call drop compensations, spectrum charge disputes, interconnection fee regulations, quality of service standards, and tariff fixation issues. The cases typically examine licence fee payments, port charges, access deficit contributions, subscriber compensation claims, and network failure liabilities.",
#             "Keywords": ["call drop", "spectrum charges", "interconnection fee", "quality of service", "tariff fixation", "licence fee", "port charges", "access deficit", "subscriber compensation", "network failure", "telecommunications regulation", "service quality", "spectrum allocation", "telecom license", "network service"],
#             "embeddings": None 
#         }
#     },

#     "HABEAS CORPUS": {
#         "Habeas Corpus": {
#             "Description": "Cases involving petitions for habeas corpus writs challenging the legality and validity of detention or confinement of individuals by state authorities or private entities. These matters address illegal detentions, production of detained persons, custody certificates, missing person investigations, and wrongful confinement allegations. The cases typically examine jurisdictional issues in custody matters, validity of preventive detentions, transfer of custody procedures, and the fundamental right to personal liberty protected under Article 21 of the Constitution.",
#             "Keywords": ["illegal detention", "custody certificate", "production order", "missing person", "wrongful confinement", "custody jurisdiction", "habeas corpus writ", "preventive detention", "custody transfer", "detention validity", "personal liberty", "unlawful confinement", "detention challenge", "custody verification", "liberty protection"],
#             "embeddings": None 
#         }
#     },

#     "APPEAL AGAINST STATUTORY BODIES": {
#         "Tribunal appeals": {
#             "Description": "Cases involving appeals against orders and decisions of various specialized tribunals including NCLT, SAT, TDSAT, and other appellate tribunals established under specific statutes. These matters address jurisdictional errors, perverse findings, substantial questions of law, limitation periods for appeals, and pre-deposit requirements. The cases typically examine the composition of tribunals, technical member appointments, and the scope of judicial review over expert tribunal decisions.",
#             "Keywords": ["NCLT order", "SAT decision", "TDSAT ruling", "appellate tribunal", "technical member", "jurisdictional error", "perverse finding", "substantial question", "limitation period", "pre-deposit", "tribunal jurisdiction", "expert body", "specialized tribunal", "appellate review", "statutory appeal"],
#             "embeddings": None 
#         }
#     },

#     "FAMILY LAW": {
#         "Child custody": {
#             "Description": "Cases involving disputes over child custody, guardianship, and access rights between parents or guardians following marital breakdown or separation. These matters address determinations of the child's best interests, parental alienation allegations, international child abduction under Hague Convention, and welfare principle applications. The cases typically examine shared custody arrangements, visitation rights, jurisdictional issues in cross-border custody disputes, and the child's preferences in custody decisions.",
#             "Keywords": ["best interest", "guardianship", "Hague convention", "parental alienation", "access rights", "child abduction", "welfare principle", "shared custody", "visitation rights", "custody jurisdiction", "child welfare", "parental rights", "custody arrangement", "cross-border custody", "child preference"],
#             "embeddings": None 
#         },
#         "Muslim marriage": {
#             "Description": "Cases involving disputes arising from Muslim marriage contracts, dissolution procedures, and matrimonial rights under Muslim personal law. These matters address mehr (dower) payments, triple talaq validity, iddat period obligations, muta marriage recognition, and nikahnama interpretations. The cases typically examine dower debt enforcement, maintenance limitations, khula and faskh dissolution procedures, and disputes over mahr amounts and payment terms.",
#             "Keywords": ["mehr", "triple talaq", "iddat period", "muta marriage", "nikahnama", "dower debt", "maintenance cap", "khula", "faskh", "mahr dispute", "Muslim law", "matrimonial rights", "dissolution procedure", "dower payment", "personal law"],
#             "embeddings": None 
#         }
#     },

#     "CONTEMPT OF COURT": {
#         "Civil contempt": {
#             "Description": "Cases involving allegations of civil contempt for willful disobedience of court orders, breach of undertakings given to courts, and violation of judicial directives. These matters address order violations, compliance reporting, contempt notices, purging of contempt, and tendered apologies. The cases typically examine the scope of contempt jurisdiction, standards for establishing willful disobedience, consequences of stay violations, and the balancing of judicial authority with individual rights.",
#             "Keywords": ["order violation", "undertaking breach", "willful disobedience", "compliance report", "contempt notice", "purge contempt", "apology tendered", "contempt jurisdiction", "stay violation", "court order", "judicial authority", "court directive", "compliance requirement", "contempt proceeding", "court dignity"],
#             "embeddings": None 
#         }
#     },

#     "ORDINARY CIVIL MATTERS": {
#         "Specific performance": {
#             "Description": "Cases involving claims for specific performance of contracts under the Specific Relief Act, where parties seek enforcement of contractual obligations rather than monetary compensation. These matters address demonstrations of readiness and willingness to perform contractual duties, discretionary nature of the relief, and alternative relief options. The cases typically examine contract validity, time essence clauses, part performance doctrines, title clearance issues, and the balance between specific enforcement and damages under Section 20 of the Specific Relief Act.",
#             "Keywords": ["readiness willingness", "contract enforcement", "alternative relief", "section 20", "discretionary relief", "mutual consent", "time essence", "part performance", "contract validity", "title clearance", "contractual obligation", "relief grant", "performance decree", "equitable relief"],
#             "embeddings": None 
#         },
#         "Electricity disputes": {
#             "Description": "Cases involving disputes in the electricity sector, including tariff determinations, cross-subsidy mechanisms, open access regulations, and regulatory compliance issues. These matters address wheeling charges, electricity theft allegations, connection denials, meter tampering investigations, and power purchase agreements. The cases typically examine regulatory asset recognition, renewable purchase obligations, and the balancing of consumer interests with utility viability in the power sector.",
#             "Keywords": ["tariff order", "cross subsidy", "open access", "wheeling charges", "electricity theft", "connection denial", "meter tampering", "regulatory asset", "power purchase", "renewable obligation", "electricity regulation", "power sector", "utility dispute", "regulatory compliance", "energy law"],
#             "embeddings": None 
#         }
#     },

#     "BENCH STRENGTH": {
#         "Constitution Bench": {
#             "Description": "Cases heard by Constitution Benches of the Supreme Court involving substantial questions of constitutional interpretation and challenges to constitutional amendments. These matters address the basic structure doctrine, federalism disputes, judicial independence challenges, and constitutional validity of landmark legislation. The cases typically examine presidential references under Article 143, constitutional morality principles, and the evolving interpretation of fundamental rights and directive principles.",
#             "Keywords": ["basic structure doctrine", "article 145(3) reference", "constitutional amendment validity", "federalism dispute resolution", "judicial independence challenge", "land acquisition constitutional validity", "reservation constitutional limit", "presidential reference article 143", "kesavananda bharati ratio", "constitutional morality violation", "constitutional interpretation", "fundamental rights", "constitutional validity", "landmark judgment", "constitutional principle"],
#             "embeddings": None 
#         }
#     },

#     "APPOINTMENTS": {
#         "Judicial appointments": {
#             "Description": "Cases involving the appointment, elevation, and transfer of judges to various constitutional courts through the collegium system and related procedures. These matters address memorandum of procedure compliance, seniority norms, elevation criteria, and considerations of judicial independence. The cases typically examine appointment delays, zone considerations, merit versus seniority balances, parent high court claims, and the appointment of additional judges.",
#             "Keywords": ["collegium system", "memorandum procedure", "seniority norm", "elevation criteria", "judicial independence", "appointment delay", "zone consideration", "merit vs seniority", "parent high court", "additional judge", "judicial appointment", "court composition", "appointment process", "judiciary independence", "judicial transfer"],
#             "embeddings": None 
#         }
#     },

#     "PERSONAL LAW": {
#         "Inheritance disputes": {
#             "Description": "Cases involving succession and inheritance disputes under various personal laws governing Hindus, Muslims, Christians, Parsis, and other communities. These matters address coparcenary rights in joint family properties, ancestral property claims, testamentary succession under wills, and legal heir determinations. The cases typically examine succession certificate requirements, inheritance rights under different religious personal laws, and the interplay between personal laws and secular succession statutes.",
#             "Keywords": ["coparcenary rights, ancestral property, testamentary succession, hindu succession, muslim inheritance, christian succession, parsi succession, legal heir, succession certificate, joint family, inheritance right, succession law, will validity, heir determination, property succession"],
#             "embeddings": None 
#         }
#     },

#     "RELIGIOUS ENDOWMENTS": {
#         "Temple management": {
#             "Description": "Cases involving the administration, management, and governance of religious endowments, temples, and religious institutions under various state endowment acts and trust laws. These matters address the appointment and removal of mathadhipatis (monastic heads), shebait rights (temple custodians), juristic status of idols, and the management of temple funds and properties. The cases typically examine the balance between religious autonomy and state supervision, appointment of archakas (priests), preservation of religious practices, and the secular management of religious institutions.",
#             "Keywords": ["mathadhipati", "shebait rights", "idol juristic", "religious endowment", "trustee removal", "dharmakarta", "archaka appointment", "temple funds", "secular management", "religious practice", "temple administration", "religious trust", "endowment act", "religious authority", "property management"],
#             "embeddings": None 
#     }
#     },

#     "MERCANTILE LAWS": {
#         "Banking disputes": {
#             "Description": "Cases involving disputes between banks, financial institutions, and their customers regarding loan agreements, debt recovery, and banking operations. These matters address SARFAESI Act proceedings, NPA classifications, wilful defaulter declarations, guarantor liabilities, and account fraud allegations. The cases typically examine cheque bounce cases under Negotiable Instruments Act, bank guarantee enforcements, loan recall procedures, and compliance with priority sector lending requirements.",
#             "Keywords": ["sarfaesi", "npa classification", "debt recovery", "wilful defaulter", "guarantor liability", "account fraud", "cheque bounce", "bank guarantee", "loan recall", "priority sector", "banking regulation", "financial dispute", "loan recovery", "banking operation", "financial institution"],
#             "embeddings": None 
#     }
#     },

#     "JUDICIARY MATTERS": {
#         "Judicial service": {
#             "Description": "Cases concerning the administration, organization, and functioning of the judicial system, including appointments, infrastructure, and ethical standards. These matters address the creation of All India Judicial Service, functioning of judicial academies, court infrastructure development, and judicial accountability mechanisms. The cases typically examine case management systems, protection of judicial independence, court automation initiatives, judicial ethics standards, work allocation procedures, and maintenance of judicial discipline.",
#             "Keywords": ["all india service", "judicial academy", "court infrastructure", "judicial accountability", "case management", "judicial independence", "court automation", "judicial ethics", "work allocation", "judicial discipline", "judiciary administration", "court management", "judicial reform", "justice delivery", "court system"],
#             "embeddings": None 
#     }
#     },

#     "MEDICAL EDUCATION": {
#         "NEET disputes": {
#             "Description": "Cases involving challenges and disputes related to the National Eligibility-cum-Entrance Test (NEET) for medical admissions across India. These matters address the implementation of All India Quota, state reservation policies, marks normalization procedures, and OMR sheet evaluation challenges. The cases typically examine percentile system calculations, eligibility criteria disputes, exam postponement issues, counselling process irregularities, and NRI quota allocations in medical colleges.",
#             "Keywords": ["neet ug", "all india quota", "state reservation", "marks normalization", "omr challenge", "percentile system", "eligibility criteria", "exam postponement", "counselling process", "nri quota", "medical admission", "entrance exam", "admission process", "quota system", "exam conduct"],
#             "embeddings": None 
#     }
#     },

#     "GOVERNMENT CONTRACTS": {
#         "Tender disputes": {
#             "Description": "Cases involving challenges to government tender processes, bid evaluations, and contract awards under public procurement policies and constitutional principles. These matters address bid eligibility criteria, technical score assessments, arbitrary rejections, pre-qualification requirements, and tender condition interpretations. The cases typically examine commercial bid evaluations, L1 bidder rejections, blacklisting orders, bid security forfeitures, and valid grounds for tender cancellations, while balancing administrative discretion with principles of fairness and transparency in public contracting.",
#             "Keywords": ["bid eligibility", "technical score", "arbitrary rejection", "pre-qualification", "tender condition", "commercial bid", "L1 rejection", "blacklisting order", "bid security", "tender cancellation", "public procurement", "tender process", "bid evaluation", "government contract", "transparency requirement"],
#             "embeddings": None 
#     }
#     },

#     "MINES & MINERALS": {
#         "Mining leases": {
#             "Description": "Cases involving the grant, renewal, regulation, and termination of mining leases and concessions under various mineral development acts and regulations. These matters address renewal rejections, mining plan approvals, environmental clearances, royalty payment disputes, and stamp duty calculations. The cases typically examine mining auction procedures, captive mining rights, mineral rights allocations, quarry lease conditions, and district mineral foundation contributions under the sustainable development framework.",
#             "Keywords": ["renewal rejection", "mining plan", "environment clearance", "royalty payment", "stamp duty", "mining auction", "captive mining", "mineral rights", "quarry lease", "district mineral", "mining regulation", "mineral concession", "sustainable mining", "resource allocation", "mining rights"],
#             "embeddings": None 
#     }
#     },

#     "CONSUMER PROTECTION": {
#         "Deficiency of service": {
#             "Description": "Cases involving allegations of deficient services across various sectors including healthcare, banking, insurance, telecommunications, and professional services under consumer protection laws. These matters address definitions of deficiency, medical negligence claims, housing project delays, banking service failures, and insurance claim repudiations. The cases typically examine telecom service quality issues, professional service deficiencies, compensation calculations for service failures, unfair contract terms, and product liability determinations.",
#             "Keywords": ["deficiency defined", "medical negligence", "housing delay", "banking service", "insurance claim", "telecom service", "professional service", "deficiency compensation", "unfair contract", "product liability", "consumer rights", "service quality", "compensation claim", "consumer forum", "service deficiency"],
#             "embeddings": None 
#     }
#     },

#     "ARMED FORCES": {
#         "Military law": {
#             "Description": "Cases involving the application of military justice systems, service conditions, and disciplinary matters under various armed forces acts and regulations. These matters address court martial procedures, summary trials, command responsibility determinations, military pension claims, and service record corrections. The cases typically examine promotion policies, resettlement benefits, disability pension entitlements, martial law declarations, and the balance between military discipline and fundamental rights under the Army Act and related legislation.",
#             "Keywords": ["court martial", "summary trial", "command responsibility", "military pension", "service record", "promotion policy", "resettlement benefits", "disability pension", "martial law", "army act", "military justice", "armed forces", "service benefits", "disciplinary proceeding", "defense personnel"],
#             "embeddings": None 
#     }
#     },

#     "CONSTITUTIONAL MATTERS": {
#         "Federal disputes": {
#             "Description": "Cases involving disputes between the Union and States or between different States regarding constitutional powers, resource allocations, and jurisdictional boundaries under the federal framework. These matters address inter-state water disputes, border demarcation controversies, language rights protections, and state autonomy questions. The cases typically examine Governor's powers, President's Rule impositions, legislative competence determinations, Concurrent List interpretations, residuary powers allocations, and the validity of Central ordinances affecting state subjects.",
#             "Keywords": ["inter-state water", "border dispute", "language rights", "state autonomy", "governor powers", "president rule", "legislative competence", "concurrent list", "residuary powers", "central ordinance", "federal structure", "center-state relations", "constitutional power", "state jurisdiction", "union authority"],
#             "embeddings": None 
#     }
#     }
# }

# with open('legal_taxonomy.json', 'w', encoding='utf-8') as f:
#     json.dump(taxonomy, f, indent=2, ensure_ascii=False)

# %%
import json

taxonomy = {
    
        "Dismissal": {
            "Description": "Cases involving termination of employment, disciplinary actions, and procedural fairness in employment termination. These cases typically address issues of misconduct investigations, show-cause procedures, compliance with natural justice principles, validity of departmental inquiries, and legal challenges to termination decisions. The matters often revolve around procedural irregularities, evidence evaluation in disciplinary proceedings, and the rights of employees during termination processes.",
            "Keywords": ["termination", "misconduct", "disciplinary action", "show cause notice", "natural justice violation", "departmental inquiry", "charge sheet", "termination benefits", "wrongful dismissal", "disciplinary proceedings", "procedural fairness", "inquiry report", "punishment proportionality", "reinstatement", "back wages"],
            "embeddings": None 
        },
        "Retrenchment": {
            "Description": "Cases concerning reduction of workforce, closure of establishments, and legal compliance with retrenchment procedures. These matters involve interpretation of retrenchment compensation calculations, compliance with statutory notice periods, government permissions for large-scale retrenchment, application of \"last in first out\" principle, and challenges to closure decisions. The cases often address economic reasons justification, alternative employment arrangements, and worker rehabilitation measures.",
            "Keywords": ["retrenchment compensation", "section 25N", "layoff", "closure", "retrenchment notice", "industrial disputes act 1947", "compensation calculation", "last come first go", "government permission", "retrenchment approval", "workforce reduction", "establishment closure", "retrenchment legality", "severance package", "voluntary retirement scheme"],
            "embeddings": None 
        },
        "Contract Labour": {
            "Description": "Cases dealing with regulation of contract labor, responsibilities of principal employers, and rights of contract workers. These matters involve determinations of genuine versus sham contract arrangements, licensing requirements for contractors, application of abolition notifications, and liabilities for unpaid wages or benefits. The cases often address triangular employment relationships, compliance with contract labor regulations, and claims for regularization of contract workers.",
            "Keywords": ["contract labour regulation", "principal employer", "licensing contractor", "abolition notification", "sham contract", "tripartite agreement", "labour commissioner", "contract worker benefits", "section 10", "direct employment", "labor contractor", "manpower supplier", "deemed employment", "equal pay equal work", "contract labor prohibition"],
            "embeddings": None 
        },
        "Matters relating to wages": {
            "Description": "Cases concerning wage disputes, salary structures, and remuneration rights under various labor laws. These matters involve claims for minimum wage compliance, dearness allowance revisions, pay parity disputes, arrears calculations, and wage board recommendations implementation. The cases often address interpretations of wage definitions, overtime calculations, and comparative wage structures across industries.",
            "Keywords": ["minimum wages", "wage revision", "dearness allowance", "pay parity", "arrears calculation", "wage board", "equal remuneration", "basic pay", "allowances dispute", "wage regularization", "overtime wages", "bonus payment", "salary structure", "wage fixation", "pay commission recommendations"],
            "embeddings": None 
        },
        "Workmen Compensation Act": {
            "Description": "Cases involving compensation for employment-related injuries, occupational diseases, and employer liability for workplace accidents. These matters address assessment of disablement percentages, dependency benefit calculations, occupational disease notifications, and employer insurance requirements. The cases often involve medical evidence evaluation, causal connection between employment and injury, and compensation commissioner appeals.",
            "Keywords": ["employment injury schedule iii", "section 3 employer liability", "occupational disease notification", "disablement percentage assessment", "compensation commissioner appeal", "dependency benefits calculation", "employer liability insurance", "accident arising employment", "mesothelioma compensation", "silicosis diagnosis report", "work-related injury", "permanent disability", "temporary disablement", "compensation calculation", "employer negligence"],
            "embeddings": None 
        },
        "ESI": {
            "Description": "Cases pertaining to Employees' State Insurance benefits, contribution compliance, and medical care entitlements. These matters involve disputes over ESI registration, contribution calculations, medical benefit claims, disability assessments, and dependent benefits. The cases often address eligibility criteria, contribution periods, and interpretation of ESI regulations for different establishment types.",
            "Keywords": ["employees state insurance", "esi contribution", "medical benefit", "disability benefit", "dependent benefit", "esi corporation", "section 46", "insurable employment", "registration certificate", "benefit period", "esi hospital", "sickness benefit", "maternity benefit", "medical board", "contribution recovery"],
            "embeddings": None 
        },
        "Factory Act": {
            "Description": "Cases concerning compliance with factory regulations, occupational health and safety standards, and working conditions in manufacturing establishments. These matters involve factory licensing requirements, occupier liabilities, hazardous process regulations, and safety measure implementations. The cases often address violations of health standards, safety officer appointments, and worker facility provisions.",
            "Keywords": ["factory license", "occupier liability", "hazardous process", "section 7A", "annual leave", "health measures", "safety officer", "canteen facilities", "creche facility", "dangerous machinery", "factory premises", "safety standards", "occupational health", "working hours", "hazardous chemicals"],
            "embeddings": None 
        },
        "Industrial Employment (Standing Order)": {
            "Description": "Cases dealing with certification of standing orders, service condition regulations, and workplace rule implementations. These matters involve disputes over standing order certifications, classification of workers, shift working arrangements, and leave rule applications. The cases often address modifications to standing orders, disciplinary procedures, and grievance redressal mechanisms.",
            "Keywords": ["standing order certification", "service rules", "shift working", "attendance", "leave rules", "classification of workers", "suspension pending inquiry", "holiday list", "termination procedure", "grievance redressal", "certified standing orders", "service conditions", "work rules", "misconduct definition", "inquiry procedure"],
            "embeddings": None 
        },
        "Payment of Gratuity Act": {
            "Description": "Cases involving gratuity payments, eligibility criteria, and calculation disputes upon termination of employment. These matters address gratuity calculation methods, forfeiture conditions, employer default in payment, and recovery procedures. The cases often involve interpretations of continuous service, superannuation definitions, and valid grounds for gratuity denial.",
            "Keywords": ["gratuity calculation", "section 4", "forfeiture of gratuity", "gratuity eligibility", "employer default", "gratuity recovery", "superannuation", "continuous service", "gratuity payment", "nomination", "gratuity authority", "time limit", "gratuity claim", "maximum gratuity", "gratuity dispute"],
            "embeddings": None 
        },
        "Trade Unions Act": {
            "Description": "Cases concerning trade union registration, recognition disputes, and collective bargaining rights. These matters involve trade union registration procedures, recognition disputes, unfair labor practice allegations, and union election controversies. The cases often address verification of membership claims, protected workmen status, and collective bargaining agreement interpretations.",
            "Keywords": ["trade union registration", "section 8", "unfair labor practice", "recognition dispute", "union elections", "membership verification", "collective bargaining", "union funds", "protected workmen", "union rivalry", "trade union rights", "collective agreement", "union recognition", "labor practices", "union activities"],
            "embeddings": None 
        },
    
    
    
        "Eviction matters of personal necessity": {
            "Description": "Cases involving eviction petitions filed by landlords for bona fide personal requirement of the premises. These matters address genuine needs for self-occupation, family expansion requirements, comparative hardship between landlord and tenant, and adequacy of alternative accommodation arrangements. The cases typically involve detailed examination of landlord's actual requirements, family circumstances, and the authenticity of the claimed necessity.",
            "Keywords": ["bona fide need", "self-occupation", "family expansion", "alternative accommodation", "comparative hardship", "landlord requirement", "residential purpose", "dependent family", "business expansion", "medical necessity", "genuine requirement", "personal use", "family member accommodation", "commercial need", "occupation bona fides"],
            "embeddings": None 
        },
        "Eviction matters for re-building": {
            "Description": "Cases concerning eviction for substantial reconstruction, demolition, or redevelopment of premises. These matters involve structural safety concerns, municipal notices for demolition, architectural certifications, redevelopment agreements, and tenant rehabilitation plans. The cases typically examine the bona fides of reconstruction plans, financial arrangements for rebuilding, and temporary accommodation arrangements for displaced tenants.",
            "Keywords": ["structural alteration", "demolition notice", "municipal notice", "reconstruction plan", "architect certificate", "building stability", "redevelopment agreement", "tenant relocation", "construction permission", "completion bond", "structural safety", "rebuilding necessity", "development permission", "temporary accommodation", "restoration guarantee"],
            "embeddings": None 
        },
        "Eviction matters of sub-letting": {
            "Description": "Cases involving unauthorized sub-letting, parting with possession, and illegal transfer of tenancy rights. These matters address allegations of sub-letting without consent, creation of license agreements, possession by third parties, and violation of tenancy terms. The cases typically involve evidence of rent receipts to third parties, possession patterns, and documentation of unauthorized arrangements.",
            "Keywords": ["unauthorized occupant", "sub-tenant", "parting possession", "license agreement", "tenancy rights", "rent receipt", "tenant verification", "lock-out period", "lease violation", "third party possession", "illegal transfer", "consent requirement", "tenancy violation", "possession proof", "sub-letting evidence"],
            "embeddings": None 
        },
        "Arrears of rent": {
            "Description": "Cases concerning non-payment of rent, calculation of arrears, and recovery of dues from tenants. These matters involve disputes over standard rent fixation, monthly rent payments, default periods, interest calculations on arrears, and deposit schemes. The cases typically examine rent payment records, notice periods for demand, and validity of rent enhancement claims.",
            "Keywords": ["rent default", "monthly rent", "standard rent", "rent enhancement", "deposit scheme", "tenant default", "arrears calculation", "interest on arrears", "money decree", "rent receipt", "rent demand", "payment default", "arrears recovery", "rent determination", "payment proof"],
            "embeddings": None 
        },
        "Enhancement of rent": {
            "Description": "Cases involving applications for rent increase based on fair rent principles, market rates, and statutory provisions. These matters address fair rent fixation, market rate determinations, cost index applications, capital value assessments, and improvement cost considerations. The cases typically involve expert valuation reports, comparative rent analyses, and interpretations of rent control legislation provisions.",
            "Keywords": ["fair rent", "market rate", "rent control act", "cost index", "capital value", "improvement cost", "section 6", "prevailing rent", "landlord application", "tenant objection", "rent fixation", "valuation report", "reasonable rent", "statutory enhancement", "rent revision"],
            "embeddings": None 
        },
    

    
        "Income Tax Reference": {
            "Description": "Cases involving references to High Courts on substantial questions of law arising from Income Tax Appellate Tribunal orders. These matters address complex legal interpretations of tax provisions, jurisdictional issues, and substantial questions of law requiring judicial clarification. The cases typically examine whether a question of law arises from tribunal decisions, the substantiality of the legal issue, and the proper interpretation of tax statutes in contentious matters.",
            "Keywords": ["substantial question of law", "section 256", "high court reference", "tax tribunal order", "case stated", "appellate reference", "tax evasion", "assessment year", "revision petition", "tax deduction", "legal interpretation", "tribunal order", "tax appeal", "reference jurisdiction", "question of law"],
            "embeddings": None 
        },
        "Wealth Tax Act": {
            "Description": "Cases concerning valuation and taxation of net wealth under the Wealth Tax Act. These matters involve disputes over asset valuation methodologies, classification of assets as productive or unproductive, valuation date determinations, and exemptions claims. The cases typically address property valuations, jewellery assessments, urban land classifications, and compliance with wealth tax return filing requirements.",
            "Keywords": ["net wealth", "asset valuation", "urban land", "unproductive assets", "valuation date", "wealth statement", "exempt assets", "jewellery valuation", "section 17 wealth tax", "wealth tax return", "asset classification", "valuation method", "wealth computation", "taxable wealth", "assessment proceedings"],
            "embeddings": None 
        },
        "Capital Gains": {
            "Description": "Cases involving taxation of capital gains from transfer of capital assets under income tax provisions. These matters address determinations of capital asset classification, transfer definitions under section 2(47), indexation benefits, long-term versus short-term gains, and exemption claims under various sections. The cases typically examine sale consideration valuations, cost inflation index applications, and exemption eligibility criteria.",
            "Keywords": ["capital asset", "transfer u/s 2(47)", "indexation benefit", "long term gain", "cost inflation index", "section 54", "exemption claim", "sale consideration", "capital gains bond", "stamp duty value", "capital gains computation", "transfer definition", "exemption qualification", "indexed cost", "capital gains tax"],
            "embeddings": None 
        },
        "Re-assessment": {
            "Description": "Cases concerning reopening of income tax assessments beyond the normal assessment period. These matters address validity of reassessment proceedings under section 147, reasons recorded for income escapement, fresh material discoveries, and limitation period compliance. The cases typically examine whether reassessment is based on change of opinion or new information, and the jurisdictional validity of reopening assessments.",
            "Keywords": ["reopening assessment", "section 147", "income escapement", "reasons recorded", "change of opinion", "fresh material", "limitation period", "notice validity", "concealment income", "undisclosed investment", "reassessment validity", "income suppression", "new information", "jurisdictional grounds", "reassessment proceedings"],
            "embeddings": None 
        },
        "Settlement Commission": {
            "Description": "Cases involving applications before the Income Tax Settlement Commission for resolution of tax disputes through settlement mechanisms. These matters address full disclosure requirements, immunity petitions, settlement terms negotiation, and finality of settlement orders. The cases typically examine the maintainability of settlement applications, disclosure completeness, and the commission's jurisdiction in pending cases.",
            "Keywords": ["settlement application", "full disclosure", "immunity petition", "settlement order", "undisclosed income", "section 245C", "commission hearing", "settlement terms", "case pending", "finality of order", "settlement jurisdiction", "disclosure adequacy", "immunity grant", "settlement terms", "commission powers"],
            "embeddings": None 
        },
    

    
        "Interpretation of the Customs Act": {
            "Description": "Cases involving the interpretation and application of provisions under the Customs Act, 1962, including valuation of imported goods, classification disputes, exemption claims, and procedural compliance requirements. These matters address determinations of customs value under Section 14, validity of bills of entry, baggage rule applications, prohibited goods classifications, and project import regulations. The cases typically examine customs duty calculations, exemption certificate validities, import manifest compliance, and appellate mechanisms under customs law.",
            "Keywords": ["customs valuation", "bill of entry", "section 14", "import manifest", "baggage rules", "prohibited goods", "customs duty exemption", "project imports", "redeployment certificate", "customs appeal", "customs duty", "goods classification", "import regulation", "duty calculation", "customs procedures"],
            "embeddings": None 
        },
        "Central Excise Act": {
            "Description": "Cases concerning the manufacture, removal, and taxation of excisable goods under the Central Excise Act, 1944 and related regulations. These matters address determinations of what constitutes a manufacturing process, CENVAT credit availment and utilization, duty demand notices, MODVAT schemes, and factory gate clearances. The cases typically involve interpretations of excise tariff classifications, valuation of excisable goods, compliance with Rule 6 provisions, and remission of duty procedures.",
            "Keywords": ["excisable goods", "cenvat credit", "manufacturing process", "rule 6", "clearance certificate", "duty demand notice", "modvat", "central excise tariff", "factory gate", "removal of goods", "excise duty", "manufacture definition", "credit utilization", "duty payment", "excise assessment"],
            "embeddings": None 
        },
        "Service Tax": {
            "Description": "Cases involving the levy, assessment, and recovery of service tax under the Finance Act, 1994, covering diverse service categories and compliance requirements. These matters address determinations of taxable services, reverse charge mechanisms, mega exemption notifications, place of provision rules, and point of taxation concepts. The cases typically examine export of service qualifications, input service distributor mechanisms, works contract compositions, and service tax audit procedures.",
            "Keywords": ["taxable service", "reverse charge", "mega exemption", "place of provision", "point of taxation", "export of service", "input service distributor", "service tax audit", "abatement claim", "works contract", "service tax", "tax liability", "exemption notification", "service classification", "tax assessment"],
            "embeddings": None 
        },
        "Anti Dumping Duty": {
            "Description": "Cases concerning the imposition and review of anti-dumping duties to protect domestic industries from unfairly priced imported goods under the Customs Tariff Act, 1975. These matters address calculations of dumping margins, injury determinations to domestic industry, designated authority investigations, and like article comparisons. The cases typically examine normal value determinations, landed value calculations, provisional duty impositions, sunset reviews, and reference price establishments.",
            "Keywords": ["margin of dumping", "injury determination", "designated authority", "like article", "normal value", "landed value", "provisional duty", "sunset review", "domestic industry", "reference price", "dumping duty", "trade remedy", "injury analysis", "investigation procedure", "duty imposition"],
            "embeddings": None 
        },
    
    
        "Capital punishment": {
            "Description": "Cases involving the imposition and confirmation of the death penalty, representing the most severe punishment in the criminal justice system. These matters address the \"rarest of rare\" doctrine, balancing aggravating and mitigating circumstances, and constitutional challenges to capital punishment. The cases typically involve exhaustive review of crime brutality, criminal antecedents, rehabilitation possibilities, and societal impact, with multiple layers of judicial scrutiny from trial courts to Supreme Court confirmation hearings.",
            "Keywords": ["rarest of rare", "death sentence confirmation", "section 302 IPC", "aggravating factors", "mitigating circumstances", "deterrent punishment", "execution warrant", "mercy petition", "death row convict", "commutation plea", "capital punishment", "sentence balancing", "constitutional validity", "judicial review", "sentencing philosophy"],
            "embeddings": None 
        },
        "Dowry death": {
            "Description": "Cases involving deaths of married women under suspicious circumstances within seven years of marriage, with allegations of dowry-related harassment. These matters address statutory presumptions under Section 304B IPC, proof of dowry demands \"soon before death,\" and evidence of cruelty and harassment. The cases typically examine matrimonial history, financial transactions, domestic violence patterns, and the recovery of stridhan (bridal wealth).",
            "Keywords": ["section 304B", "dowry demand", "soon before death", "cruelty evidence", "stridhan recovery", "domestic violence", "marriage harassment", "dowry prohibition", "bride burning", "death within 7 years", "dowry harassment", "statutory presumption", "matrimonial cruelty", "harassment proof", "dowry death presumption"],
            "embeddings": None 
        },
        "Prevention of Corruption Act": {
            "Description": "Cases involving corruption offenses by public servants, including bribery, illegal gratification, and possession of disproportionate assets. These matters address trap cases, validity of sanction for prosecution, evidence of demand and acceptance of bribes, and calculations of disproportionate wealth. The cases typically involve vigilance investigations, recovery operations, and examination of asset declarations versus known income sources.",
            "Keywords": ["illegal gratification", "trap case", "disproportionate assets", "section 13", "public servant", "vigilance inquiry", "sanction prosecution", "bribe money", "demand proof", "recovery certificate", "corruption offense", "public duty abuse", "wealth discrepancy", "graft evidence", "anticorruption law"],
            "embeddings": None 
        },
        "NDPS Act": {
            "Description": "Cases involving offenses under the Narcotic Drugs and Psychotropic Substances Act, covering possession, trafficking, and distribution of controlled substances. These matters address determinations of commercial quantities, conscious possession requirements, compliance with sampling and seizure procedures, and mandatory minimum sentences. The cases typically examine chain of custody evidence, independent witness reliability, and forensic analysis of contraband.",
            "Keywords": ["commercial quantity", "psychotropic substance", "section 37", "conscious possession", "sampling procedure", "independent witness", "mandatory minimum", "contraband seizure", "drug analysis", "cartel involvement", "narcotics offense", "controlled substance", "trafficking quantity", "seizure compliance", "drug trade"],
            "embeddings": None 
        },
        "Sexual harassment": {
            "Description": "Cases involving various forms of sexual offenses against women, including outraging modesty, workplace harassment, stalking, and voyeurism. These matters address evidence collection in sensitive cases, victim protection mechanisms, compensation awards, and implementation of the POSH Act for workplace safety. The cases typically examine victim testimony reliability, circumstantial evidence, and the psychological impact on survivors.",
            "Keywords": ["section 354", "modesty outrage", "voyeurism", "stalking", "workplace harassment", "POSH Act", "zero FIR", "acid attack", "compensation award", "victim protection", "sexual offense", "women safety", "harassment evidence", "victim testimony", "gender-based violence"],
            "embeddings": None 
        },
    

        "Promotion": {
            "Description": "Cases involving disputes related to promotion policies, seniority considerations, departmental promotion committees, and implementation of reservation rosters in government and public sector employment. These matters address criteria for promotion, merit versus seniority balances, sealed cover procedures for pending disciplinary cases, and the proper constitution and functioning of DPCs. The cases typically examine promotion policies, eligibility lists, benchmarking standards, and notional promotions with consequential benefits.",
            "Keywords": ["seniority cum merit", "departmental promotion", "reservation roster", "sealed cover procedure", "dpc meeting", "eligible list", "promotion criteria", "benchmarking", "notional promotion", "promotion policy", "seniority list", "promotion quota", "selection process", "promotion dispute", "departmental promotion committee"],
            "embeddings": None 
        },
        "Pension": {
            "Description": "Cases concerning pensionary benefits, revisions, commutations, family pensions, and gratuity payments for government employees and public sector workers. These matters address qualifying service calculations, pension sanction procedures, delays in pension processing, invalid pension claims, and pension cuts due to disciplinary actions. The cases typically involve interpretations of pension rules, revision schemes, and entitlement determinations based on service duration and conditions.",
            "Keywords": ["pension revision", "commutation amount", "family pension", "gratuity payment", "pension sanction", "qualifying service", "invalid pension", "delay in pension", "pension cut", "pensionary benefits", "pension calculation", "retirement benefits", "pension entitlement", "pension disbursement", "superannuation benefits"],
            "embeddings": None 
        },
        "Disciplinary proceedings": {
            "Description": "Cases involving departmental inquiries, charge memos, penalty impositions, and procedural compliance in disciplinary actions against employees. These matters address evidence act applications in departmental inquiries, validity of charge sheets, proportionality of punishments, CVC guideline compliance, and inquiry procedure fairness. The cases typically examine inquiry officer appointments, defense assistant rights, ex parte proceedings, and the distinction between minor and major penalties.",
            "Keywords": ["charge memo", "departmental inquiry", "evidence act violation", "punishment order", "minor penalty", "major penalty", "cvc guidelines", "inquiry officer", "defense assistant", "ex parte inquiry", "disciplinary action", "procedural fairness", "penalty imposition", "inquiry report", "misconduct proof"],
            "embeddings": None 
        },
        "Reservation in service": {
            "Description": "Cases concerning implementation of reservation policies, creamy layer exclusions, roster systems, and carry forward rules in public employment. These matters address Mandal Commission recommendations, reservation ceilings, promotion reservations, social backwardness determinations, and caste certificate validities. The cases typically examine income criteria for creamy layer exclusion, roster point operations, and constitutional validity of various reservation provisions.",
            "Keywords": ["creamy layer reservation", "reservation policy service", "mandal commission", "roster system", "carry forward rule", "promotion reservation", "reservation ceiling", "social backwardness", "income criteria", "caste certificate", "reservation quota", "backward class", "reservation entitlement", "roster point", "caste validity"],
            "embeddings": None 
        },
        "Voluntary Retirement": {
            "Description": "Cases involving voluntary retirement schemes, acceptance conditions, distinction from resignation, and post-retirement benefits. These matters address VR scheme eligibility, notice period requirements, pension eligibility after voluntary retirement, forced retirement allegations, and golden handshake arrangements. The cases typically examine whether retirement was truly voluntary, compliance with scheme conditions, and calculation of retirement benefits under voluntary separation plans.",
            "Keywords": ["vr scheme", "acceptance condition", "resignation difference", "pension eligibility", "notice period", "vr benefits", "forced retirement", "section 18", "voluntary separation", "golden handshake", "voluntary retirement", "retirement benefits", "scheme eligibility", "voluntary separation benefits", "retirement acceptance"],
            "embeddings": None 
        },

        "Compensation challenges": {
            "Description": "Cases involving disputes over the adequacy and calculation of compensation awarded for land acquired under the Land Acquisition Act and related legislation. These matters address determinations of market value under Section 23, solatium payments, additional compensation claims, and valuation methodologies for different types of land. The cases typically examine expert valuation reports, potential value considerations, belting system applications, severance compensation for partial acquisitions, and compensation for injurious affection to remaining land.",
            "Keywords": ["market value", "section 23", "solatium", "additional compensation", "potential value", "expert valuation", "land acquisition award", "belting system", "severance compensation", "injurious affection", "compensation dispute", "land valuation", "acquisition award", "value assessment", "compensation enhancement"],
            "embeddings": None 
        },
        "Defence acquisition": {
            "Description": "Cases concerning land acquisition for defence purposes, including the application of urgency clauses under Section 17, strategic requirements, and national security considerations. These matters address emergency acquisition procedures, defence production facility requirements, encroachment removal from defence lands, and establishment of buffer zones around sensitive installations. The cases typically examine the validity of urgency clause invocations, strategic purpose justifications, and compensation matters in defence-related acquisitions.",
            "Keywords": ["urgency clause", "section 17 land acquisition", "defence production", "strategic purpose", "emergency acquisition", "national security", "encroachment removal", "defence installation", "buffer zone", "restricted area", "defence land", "strategic acquisition", "emergency powers", "security zone", "defence requirement"],
            "embeddings": None 
        },

    
        "Examination matters": {
            "Description": "Cases involving disputes related to examination processes, evaluation systems, and academic assessments across educational institutions. These matters address revaluation procedures, grace mark allocations, malpractice investigations, answer sheet inspection rights, and moderation policies. The cases typically examine the fairness of evaluation processes, validity of supplementary examinations, handling of paper leakages, prevention of unfair means, and transparency in marking schemes. The courts often balance institutional autonomy with students' rights to fair assessment.",
            "Keywords": ["revaluation", "grace marks", "malpractice", "answer sheet inspection", "moderation policy", "supplementary exam", "re-test order", "paper leakage", "unfair means", "marking scheme", "examination process", "evaluation system", "answer script", "assessment fairness", "academic evaluation"],
            "embeddings": None 
        },
        "Educational management": {
            "Description": "Cases concerning the administration, regulation, and governance of educational institutions, including universities, colleges, and minority educational entities. These matters address deemed university status grants, minority institution rights, mandatory disclosure requirements, fee regulation compliance, and affiliation matters. The cases typically examine inspection report validity, teacher qualification standards, student union activities, anti-ragging measures, and implementation of reservation policies in educational institutions.",
            "Keywords": ["deemed university", "minority institution", "mandatory disclosure", "inspection report", "fee regulation", "affiliation withdrawal", "teacher qualification", "student union", "anti-ragging", "reservation policy education", "educational governance", "institutional management", "regulatory compliance", "academic administration", "educational rights"],
            "embeddings": None 
        },


        "Environmental PIL": {
            "Description": "Cases involving public interest litigation focused on environmental protection, conservation, and sustainable development principles. These matters address violations of environmental laws, improper clearances, ecological degradation, and implementation of environmental protection measures. The cases typically examine carbon emission standards, coastal regulation zone violations, forest clearance procedures, wildlife protection requirements, and application of the polluter pays principle. The courts often mandate environmental audits, remediation plans, and sustainable development practices while balancing ecological concerns with developmental needs.",
            "Keywords": ["carbon emissions", "coastal regulation", "forest clearance", "wildlife protection", "environment clearance", "biosphere reserve", "polluter pays", "sustainable development", "remediation plan", "environmental audit", "ecological balance", "environmental protection", "conservation measures", "green principle", "climate justice"],
            "embeddings": None 
        },
        "Human rights PIL": {
            "Description": "Cases concerning public interest litigation aimed at protecting and promoting fundamental human rights, particularly for marginalized and vulnerable populations. These matters address custodial violence and deaths, prison condition reforms, eradication of manual scavenging, child rights protection, and rehabilitation of victims. The cases typically examine implementation of juvenile justice mechanisms, bonded labor eradication, compensation schemes for rights violations, victim protection measures, and access to legal aid for underprivileged communities.",
            "Keywords": ["custodial death", "prison reform", "manual scavenging", "child rights", "rehabilitation plan", "bonded labour", "compensation scheme", "victim protection", "legal aid", "juvenile justice", "human rights violation", "dignity protection", "marginalised community", "rights enforcement", "social justice"],
            "embeddings": None 
        },

        "Election petitions": {
            "Description": "Cases involving challenges to the validity of election results, allegations of electoral malpractices, and disputes concerning the election process for various legislative bodies. These matters address corrupt practices such as bribery, undue influence, booth capturing, and false declarations in affidavits. The cases typically examine election expense violations, improper nomination rejections, demands for vote recounts, disputes over election symbols, result declaration procedures, electoral bond disclosures, and violations of the model code of conduct during elections.",
            "Keywords": ["corrupt practice", "booth capturing", "false affidavit", "election expenses", "nomination rejection", "vote recount", "election symbol", "result declaration", "electoral bonds", "model code violation", "electoral malpractice", "election validity", "voting process", "candidate eligibility", "election dispute"],
            "embeddings": None 
        },
        "MP/MLA disqualification": {
            "Description": "Cases concerning the disqualification of elected representatives from legislative bodies on various constitutional and legal grounds. These matters address holding offices of profit, violations of anti-defection laws, validity of resignations, and cessation of membership. The cases typically examine disqualification petitions, floor test procedures, appointments to constitutional posts, legislative privileges, and allegations of breach of oath by elected representatives.",
            "Keywords": ["office of profit", "defection law", "anti-defection", "resignation validity", "membership cessation", "disqualification petition", "floor test", "constitutional post", "legislative privileges", "breach of oath", "disqualification grounds", "legislative membership", "constitutional violation", "representative eligibility", "parliamentary conduct"],
            "embeddings": None 
        },

    
        "SEBI matters": {
            "Description": "Cases involving regulatory compliance, enforcement actions, and adjudication proceedings under the Securities and Exchange Board of India Act and related securities regulations. These matters address insider trading violations, substantial acquisition disclosures, takeover code compliance, fraudulent trade practices, and foreign institutional investor regulations. The cases typically examine disclosure norm violations, delisting procedures, share buyback offers, open offer requirements, and protection of investor interests in securities markets.",
            "Keywords": ["insider trading", "substantial acquisition", "takeover code", "disclosure norms", "fraudulent trade", "FII regulations", "creamy layer investor", "delisting shares", "buyback offer", "open offer", "securities regulation", "market manipulation", "investor protection", "compliance violation", "capital market"],
            "embeddings": None 
        },
        "Competition Commission": {
            "Description": "Cases concerning anti-competitive practices, abuse of dominant position, cartelization, and combination regulations under the Competition Act. These matters address investigations into anti-competitive agreements, abuse of market dominance, leniency applications, penalty impositions based on turnover, and market share analyses. The cases typically examine predatory pricing allegations, vertical agreement restrictions, determinations of dominant position, and merger control regulations.",
            "Keywords": ["anti-competitive", "abuse of dominance", "cartelization", "combination regulation", "leniency application", "turnover penalty", "market share", "predatory pricing", "vertical agreement", "dominant position", "competition law", "market regulation", "cartel investigation", "merger control", "anti-trust"],
            "embeddings": None 
        },

    
        "Arbitration challenges": {
            "Description": "Cases involving challenges to arbitral awards, appointment of arbitrators, and jurisdictional issues in domestic and international arbitration proceedings. These matters address setting aside awards under Section 34 of the Arbitration Act on grounds of patent illegality, public policy violations, and jurisdictional errors. The cases typically examine unilateral arbitrator appointments, emergency arbitrator provisions, interpretation of arbitration clauses, and distinctions between seat and venue of arbitration.",
            "Keywords": ["arbitral award", "section 34", "patent illegality", "public policy", "arbitrator appointment", "jurisdictional error", "unilateral appointment", "emergency arbitrator", "arbitration clause", "seat vs venue", "award challenge", "arbitration agreement", "arbitral procedure", "jurisdictional challenge", "award enforcement"],
            "embeddings": None 
        },

    
        "Railway accidents": {
            "Description": "Cases involving claims for compensation arising from railway accidents, untoward incidents, and passenger injuries under the Railways Act and Fatal Accidents Act. These matters address railway liability determinations, track negligence allegations, passenger ticket validities, level crossing accidents, and compensation tariff applications. The cases typically examine dependency claims, railway tribunal procedures, and the extent of railway responsibility for accidents and incidents.",
            "Keywords": ["untoward incident", "running train", "track negligence", "railway liability", "passenger ticket", "level crossing", "compensation tariff", "railway tribunal", "Fatal Accident Act", "dependency claim", "railway accident", "passenger safety", "accident compensation", "railway responsibility", "injury claim"],
            "embeddings": None 
        },
        "Telecom disputes": {
            "Description": "Cases involving disputes in the telecommunications sector, including service quality issues, regulatory compliance, and compensation claims. These matters address call drop compensations, spectrum charge disputes, interconnection fee regulations, quality of service standards, and tariff fixation issues. The cases typically examine licence fee payments, port charges, access deficit contributions, subscriber compensation claims, and network failure liabilities.",
            "Keywords": ["call drop", "spectrum charges", "interconnection fee", "quality of service", "tariff fixation", "licence fee", "port charges", "access deficit", "subscriber compensation", "network failure", "telecommunications regulation", "service quality", "spectrum allocation", "telecom license", "network service"],
            "embeddings": None 
        },

    
        "Habeas Corpus": {
            "Description": "Cases involving petitions for habeas corpus writs challenging the legality and validity of detention or confinement of individuals by state authorities or private entities. These matters address illegal detentions, production of detained persons, custody certificates, missing person investigations, and wrongful confinement allegations. The cases typically examine jurisdictional issues in custody matters, validity of preventive detentions, transfer of custody procedures, and the fundamental right to personal liberty protected under Article 21 of the Constitution.",
            "Keywords": ["illegal detention", "custody certificate", "production order", "missing person", "wrongful confinement", "custody jurisdiction", "habeas corpus writ", "preventive detention", "custody transfer", "detention validity", "personal liberty", "unlawful confinement", "detention challenge", "custody verification", "liberty protection"],
            "embeddings": None 
        },

    
        "Tribunal appeals": {
            "Description": "Cases involving appeals against orders and decisions of various specialized tribunals including NCLT, SAT, TDSAT, and other appellate tribunals established under specific statutes. These matters address jurisdictional errors, perverse findings, substantial questions of law, limitation periods for appeals, and pre-deposit requirements. The cases typically examine the composition of tribunals, technical member appointments, and the scope of judicial review over expert tribunal decisions.",
            "Keywords": ["NCLT order", "SAT decision", "TDSAT ruling", "appellate tribunal", "technical member", "jurisdictional error", "perverse finding", "substantial question", "limitation period", "pre-deposit", "tribunal jurisdiction", "expert body", "specialized tribunal", "appellate review", "statutory appeal"],
            "embeddings": None 
        },

    
        "Child custody": {
            "Description": "Cases involving disputes over child custody, guardianship, and access rights between parents or guardians following marital breakdown or separation. These matters address determinations of the child's best interests, parental alienation allegations, international child abduction under Hague Convention, and welfare principle applications. The cases typically examine shared custody arrangements, visitation rights, jurisdictional issues in cross-border custody disputes, and the child's preferences in custody decisions.",
            "Keywords": ["best interest", "guardianship", "Hague convention", "parental alienation", "access rights", "child abduction", "welfare principle", "shared custody", "visitation rights", "custody jurisdiction", "child welfare", "parental rights", "custody arrangement", "cross-border custody", "child preference"],
            "embeddings": None 
        },
        "Muslim marriage": {
            "Description": "Cases involving disputes arising from Muslim marriage contracts, dissolution procedures, and matrimonial rights under Muslim personal law. These matters address mehr (dower) payments, triple talaq validity, iddat period obligations, muta marriage recognition, and nikahnama interpretations. The cases typically examine dower debt enforcement, maintenance limitations, khula and faskh dissolution procedures, and disputes over mahr amounts and payment terms.",
            "Keywords": ["mehr", "triple talaq", "iddat period", "muta marriage", "nikahnama", "dower debt", "maintenance cap", "khula", "faskh", "mahr dispute", "Muslim law", "matrimonial rights", "dissolution procedure", "dower payment", "personal law"],
            "embeddings": None 
        },

    
        "Civil contempt": {
            "Description": "Cases involving allegations of civil contempt for willful disobedience of court orders, breach of undertakings given to courts, and violation of judicial directives. These matters address order violations, compliance reporting, contempt notices, purging of contempt, and tendered apologies. The cases typically examine the scope of contempt jurisdiction, standards for establishing willful disobedience, consequences of stay violations, and the balancing of judicial authority with individual rights.",
            "Keywords": ["order violation", "undertaking breach", "willful disobedience", "compliance report", "contempt notice", "purge contempt", "apology tendered", "contempt jurisdiction", "stay violation", "court order", "judicial authority", "court directive", "compliance requirement", "contempt proceeding", "court dignity"],
            "embeddings": None 
        },

    
        "Specific performance": {
            "Description": "Cases involving claims for specific performance of contracts under the Specific Relief Act, where parties seek enforcement of contractual obligations rather than monetary compensation. These matters address demonstrations of readiness and willingness to perform contractual duties, discretionary nature of the relief, and alternative relief options. The cases typically examine contract validity, time essence clauses, part performance doctrines, title clearance issues, and the balance between specific enforcement and damages under Section 20 of the Specific Relief Act.",
            "Keywords": ["readiness willingness", "contract enforcement", "alternative relief", "section 20", "discretionary relief", "mutual consent", "time essence", "part performance", "contract validity", "title clearance", "contractual obligation", "relief grant", "performance decree", "equitable relief"],
            "embeddings": None 
        },
        "Electricity disputes": {
            "Description": "Cases involving disputes in the electricity sector, including tariff determinations, cross-subsidy mechanisms, open access regulations, and regulatory compliance issues. These matters address wheeling charges, electricity theft allegations, connection denials, meter tampering investigations, and power purchase agreements. The cases typically examine regulatory asset recognition, renewable purchase obligations, and the balancing of consumer interests with utility viability in the power sector.",
            "Keywords": ["tariff order", "cross subsidy", "open access", "wheeling charges", "electricity theft", "connection denial", "meter tampering", "regulatory asset", "power purchase", "renewable obligation", "electricity regulation", "power sector", "utility dispute", "regulatory compliance", "energy law"],
            "embeddings": None 
        },

    
        "Constitution Bench": {
            "Description": "Cases heard by Constitution Benches of the Supreme Court involving substantial questions of constitutional interpretation and challenges to constitutional amendments. These matters address the basic structure doctrine, federalism disputes, judicial independence challenges, and constitutional validity of landmark legislation. The cases typically examine presidential references under Article 143, constitutional morality principles, and the evolving interpretation of fundamental rights and directive principles.",
            "Keywords": ["basic structure doctrine", "article 145(3) reference", "constitutional amendment validity", "federalism dispute resolution", "judicial independence challenge", "land acquisition constitutional validity", "reservation constitutional limit", "presidential reference article 143", "kesavananda bharati ratio", "constitutional morality violation", "constitutional interpretation", "fundamental rights", "constitutional validity", "landmark judgment", "constitutional principle"],
            "embeddings": None 
        },

    
        "Judicial appointments": {
            "Description": "Cases involving the appointment, elevation, and transfer of judges to various constitutional courts through the collegium system and related procedures. These matters address memorandum of procedure compliance, seniority norms, elevation criteria, and considerations of judicial independence. The cases typically examine appointment delays, zone considerations, merit versus seniority balances, parent high court claims, and the appointment of additional judges.",
            "Keywords": ["collegium system", "memorandum procedure", "seniority norm", "elevation criteria", "judicial independence", "appointment delay", "zone consideration", "merit vs seniority", "parent high court", "additional judge", "judicial appointment", "court composition", "appointment process", "judiciary independence", "judicial transfer"],
            "embeddings": None 
        },

    
        "Inheritance disputes": {
            "Description": "Cases involving succession and inheritance disputes under various personal laws governing Hindus, Muslims, Christians, Parsis, and other communities. These matters address coparcenary rights in joint family properties, ancestral property claims, testamentary succession under wills, and legal heir determinations. The cases typically examine succession certificate requirements, inheritance rights under different religious personal laws, and the interplay between personal laws and secular succession statutes.",
            "Keywords": ["coparcenary rights, ancestral property, testamentary succession, hindu succession, muslim inheritance, christian succession, parsi succession, legal heir, succession certificate, joint family, inheritance right, succession law, will validity, heir determination, property succession"],
            "embeddings": None 
        },

    
        "Temple management": {
            "Description": "Cases involving the administration, management, and governance of religious endowments, temples, and religious institutions under various state endowment acts and trust laws. These matters address the appointment and removal of mathadhipatis (monastic heads), shebait rights (temple custodians), juristic status of idols, and the management of temple funds and properties. The cases typically examine the balance between religious autonomy and state supervision, appointment of archakas (priests), preservation of religious practices, and the secular management of religious institutions.",
            "Keywords": ["mathadhipati", "shebait rights", "idol juristic", "religious endowment", "trustee removal", "dharmakarta", "archaka appointment", "temple funds", "secular management", "religious practice", "temple administration", "religious trust", "endowment act", "religious authority", "property management"],
            "embeddings": None 
    },

    
        "Banking disputes": {
            "Description": "Cases involving disputes between banks, financial institutions, and their customers regarding loan agreements, debt recovery, and banking operations. These matters address SARFAESI Act proceedings, NPA classifications, wilful defaulter declarations, guarantor liabilities, and account fraud allegations. The cases typically examine cheque bounce cases under Negotiable Instruments Act, bank guarantee enforcements, loan recall procedures, and compliance with priority sector lending requirements.",
            "Keywords": ["sarfaesi", "npa classification", "debt recovery", "wilful defaulter", "guarantor liability", "account fraud", "cheque bounce", "bank guarantee", "loan recall", "priority sector", "banking regulation", "financial dispute", "loan recovery", "banking operation", "financial institution"],
            "embeddings": None 
    },

    
        "Judicial service": {
            "Description": "Cases concerning the administration, organization, and functioning of the judicial system, including appointments, infrastructure, and ethical standards. These matters address the creation of All India Judicial Service, functioning of judicial academies, court infrastructure development, and judicial accountability mechanisms. The cases typically examine case management systems, protection of judicial independence, court automation initiatives, judicial ethics standards, work allocation procedures, and maintenance of judicial discipline.",
            "Keywords": ["all india service", "judicial academy", "court infrastructure", "judicial accountability", "case management", "judicial independence", "court automation", "judicial ethics", "work allocation", "judicial discipline", "judiciary administration", "court management", "judicial reform", "justice delivery", "court system"],
            "embeddings": None 
    },

    
        "NEET disputes": {
            "Description": "Cases involving challenges and disputes related to the National Eligibility-cum-Entrance Test (NEET) for medical admissions across India. These matters address the implementation of All India Quota, state reservation policies, marks normalization procedures, and OMR sheet evaluation challenges. The cases typically examine percentile system calculations, eligibility criteria disputes, exam postponement issues, counselling process irregularities, and NRI quota allocations in medical colleges.",
            "Keywords": ["neet ug", "all india quota", "state reservation", "marks normalization", "omr challenge", "percentile system", "eligibility criteria", "exam postponement", "counselling process", "nri quota", "medical admission", "entrance exam", "admission process", "quota system", "exam conduct"],
            "embeddings": None 
    },

    
        "Tender disputes": {
            "Description": "Cases involving challenges to government tender processes, bid evaluations, and contract awards under public procurement policies and constitutional principles. These matters address bid eligibility criteria, technical score assessments, arbitrary rejections, pre-qualification requirements, and tender condition interpretations. The cases typically examine commercial bid evaluations, L1 bidder rejections, blacklisting orders, bid security forfeitures, and valid grounds for tender cancellations, while balancing administrative discretion with principles of fairness and transparency in public contracting.",
            "Keywords": ["bid eligibility", "technical score", "arbitrary rejection", "pre-qualification", "tender condition", "commercial bid", "L1 rejection", "blacklisting order", "bid security", "tender cancellation", "public procurement", "tender process", "bid evaluation", "government contract", "transparency requirement"],
            "embeddings": None 
    },

    
        "Mining leases": {
            "Description": "Cases involving the grant, renewal, regulation, and termination of mining leases and concessions under various mineral development acts and regulations. These matters address renewal rejections, mining plan approvals, environmental clearances, royalty payment disputes, and stamp duty calculations. The cases typically examine mining auction procedures, captive mining rights, mineral rights allocations, quarry lease conditions, and district mineral foundation contributions under the sustainable development framework.",
            "Keywords": ["renewal rejection", "mining plan", "environment clearance", "royalty payment", "stamp duty", "mining auction", "captive mining", "mineral rights", "quarry lease", "district mineral", "mining regulation", "mineral concession", "sustainable mining", "resource allocation", "mining rights"],
            "embeddings": None 
    },

    
        "Deficiency of service": {
            "Description": "Cases involving allegations of deficient services across various sectors including healthcare, banking, insurance, telecommunications, and professional services under consumer protection laws. These matters address definitions of deficiency, medical negligence claims, housing project delays, banking service failures, and insurance claim repudiations. The cases typically examine telecom service quality issues, professional service deficiencies, compensation calculations for service failures, unfair contract terms, and product liability determinations.",
            "Keywords": ["deficiency defined", "medical negligence", "housing delay", "banking service", "insurance claim", "telecom service", "professional service", "deficiency compensation", "unfair contract", "product liability", "consumer rights", "service quality", "compensation claim", "consumer forum", "service deficiency"],
            "embeddings": None 
    },

    
        "Military law": {
            "Description": "Cases involving the application of military justice systems, service conditions, and disciplinary matters under various armed forces acts and regulations. These matters address court martial procedures, summary trials, command responsibility determinations, military pension claims, and service record corrections. The cases typically examine promotion policies, resettlement benefits, disability pension entitlements, martial law declarations, and the balance between military discipline and fundamental rights under the Army Act and related legislation.",
            "Keywords": ["court martial", "summary trial", "command responsibility", "military pension", "service record", "promotion policy", "resettlement benefits", "disability pension", "martial law", "army act", "military justice", "armed forces", "service benefits", "disciplinary proceeding", "defense personnel"],
            "embeddings": None 
    },

    
        "Federal disputes": {
            "Description": "Cases involving disputes between the Union and States or between different States regarding constitutional powers, resource allocations, and jurisdictional boundaries under the federal framework. These matters address inter-state water disputes, border demarcation controversies, language rights protections, and state autonomy questions. The cases typically examine Governor's powers, President's Rule impositions, legislative competence determinations, Concurrent List interpretations, residuary powers allocations, and the validity of Central ordinances affecting state subjects.",
            "Keywords": ["inter-state water", "border dispute", "language rights", "state autonomy", "governor powers", "president rule", "legislative competence", "concurrent list", "residuary powers", "central ordinance", "federal structure", "center-state relations", "constitutional power", "state jurisdiction", "union authority"],
            "embeddings": None 
    }
}

with open('legal_taxonomy_new.json', 'w', encoding='utf-8') as f:
    json.dump(taxonomy, f, indent=2, ensure_ascii=False)
